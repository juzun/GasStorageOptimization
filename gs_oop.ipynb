# %% [markdown]
# Libraries

# %%
import numpy as np
import pandas as pd
import datetime as dt
import plotly.graph_objects as po
import pyomo.environ as pyo
from pyomo.contrib import appsi
from typing import List, Dict, Union, Literal
import psutil

# %% [markdown]
# Class definition

# %%
from collections import defaultdict
dic = defaultdict(list)

dic['pes'].append(5)

# %%
print(dic)
# Out:
# defaultdict(<class 'list'>, {'pes': [5]})

# %%
class GasStorage():
    _instances: list = []
    _dates: List[dt.date] = []
    _total_data: pd.DataFrame = None
    _total_operations: Dict[dt.date, float] = {}
    _total_max_operations: Dict[dt.date, float] = {}
    _total_gs_state: Dict[dt.date, float] = {}
    _total_wgv: Dict[dt.date, float] = {}

    def __init__(self, name: str, date_start: dt.date, date_end: dt.date):
        self.name: str = name
        self.id: str = name + '_' + dt.datetime.now().strftime('%Y_%m_%d_%H_%M_%S_%f')
        self.date_start: dt.date = date_start
        self.date_end: dt.date = date_end
        self.attr: pd.DataFrame = None
        self.model_vals: pd.DataFrame = None
        self.__initialize_df()
        
        self.z0: int = 0
        self.empty_storage: bool = False
        self.empty_on_dates: List[dt.date] = []
        self.bsd_state_to_date: Dict[int, float] = {}
        self.injection_season: List[int] = []
        self.injection_idx: List[int] = []
        self.withdrawal_idx: List[int] = []
        self.inj_curve_daily: Dict[dt.date, float] = {}
        self.wit_curve_daily: Dict[dt.date, float] = {}
        self.mdl: pyo.ConcreteModel = None
        self.slvr: Union[appsi.solvers.Cplex, appsi.solvers.Highs] = None
        self.objective: float = None
        self.results: Union[appsi.solvers.highs.HighsResults, appsi.solvers.cplex.CplexResults] = None
        self.solved: bool = False

        self.best_objective_bound: float = None
        self.best_feasible: float = None
        self.gap: float = None

        GasStorage._instances.append(self)
    
    @property
    def dates(self) -> List[dt.date]:
        return [self.date_start + dt.timedelta(days=i) for i in range(0,(self.date_end-self.date_start).days+1)]
    
    @property
    def curve_value_type(self) -> List[str]:
        return ['lower', 'upper', 'portion']

    @property
    def attr_lbls(self) -> List[str]:
        return ['prices', 'wgv', 'ir', 'wr', 'inj_curve', 'wit_curve', 'm_const', 'bsd_wit_curve']
    
    @property
    def delta(self) -> dt.timedelta:
        return dt.timedelta(days=1)

    def __initialize_df(self) -> None:
        self.attr = pd.DataFrame(index=pd.DatetimeIndex(self.dates))
        self.attr['yyyy-mm-dd'] = self.attr.index.date
        self.attr['year'] = self.attr.index.year
        self.attr['month'] = self.attr.index.month
    
    def __transform_curve(self, curve_type: str) -> None:
        curve_dict = self.get_dict_from_column(curve_type)
        for i in self.dates:
            if curve_type == 'inj_curve':
                for j in range(len(self.injection_idx)):
                    for l in range(3):
                        self.inj_curve_daily[i, self.injection_idx[j], self.curve_value_type[l]] = curve_dict[i][l,j]
            elif curve_type == 'wit_curve':
                for k in range(len(self.withdrawal_idx)):
                    for l in range(3):
                        self.wit_curve_daily[i, self.withdrawal_idx[k], self.curve_value_type[l]] = curve_dict[i][l,k]
            else:
                raise Exception(f"Only following two types of curves are allowed: inj_curve, wit_curve.")

    def load_prices(self, path: str) -> pd.DataFrame:        
        self.prices_monthly = pd.read_excel(path, parse_dates=['date'], usecols=['date', 'price'])
        self.prices_monthly = self.prices_monthly[self.prices_monthly['date'] >= pd.to_datetime(self.date_start.replace(day=1))]
        self.prices_monthly['year'] = self.prices_monthly['date'].dt.year
        self.prices_monthly['month'] = self.prices_monthly['date'].dt.month
        self.attr['prices'] = (pd.merge(self.attr, self.prices_monthly, on=['year', 'month'])
                               .sort_values(['year', 'month'])['price'].values)

    def set_initial_state(self, z0:int) -> None:
        self.z0=z0

    def set_dates_to_empty_storage(self, empty_on_dates: List[dt.date]) -> None:
        self.empty_on_dates = empty_on_dates
        self.empty_storage = True if self.empty_on_dates else False
    
    def load_attribute(self, attr_name: str, value: Union[np.array, int], date_from: dt.date, date_to: dt.date) -> None:
        self.check_attribute_lbl(attr_name)
        if attr_name not in self.attr:
            self.attr[attr_name] = None
        selected_rows = (self.attr.index >= pd.to_datetime(date_from)) & (self.attr.index <= pd.to_datetime(date_to))
        self.attr.loc[selected_rows, attr_name] = pd.Series([value]*selected_rows.sum(), index=self.attr.index[selected_rows])
        
        if attr_name == 'wgv':
            self.load_attribute('m_const', value + 100000, date_from, date_to)        
        if attr_name == 'inj_curve':
            self.injection_idx = np.arange(1,self.attr['inj_curve'].iloc[0].shape[1]+1,1)
            self.__transform_curve(attr_name)
        if attr_name == 'wit_curve':
            self.withdrawal_idx = np.arange(1,self.attr['wit_curve'].iloc[0].shape[1]+1,1)
            self.__transform_curve(attr_name)

    def reset_attribute(self, attr_name: str) -> None:
        self.check_attribute_lbl(attr_name)
        self.attr[attr_name] = None

    def check_attribute_lbl(self, attr_name: str) -> None:
        if attr_name not in self.attr_lbls:
            raise Exception(f"Only following attributes are allowed: {', '.join(item for item in self.attr_lbls)}.")
    
    def remove_attribute(self, attr_name: str) -> None:
        if attr_name in self.attr:
            self.attr = self.attr.drop(columns=[attr_name])
    
    def set_state_to_date(self, bsd_state_to_date: Dict[int, float]) -> None:
        self.bsd_state_to_date = bsd_state_to_date
    
    def set_injection_season(self, injection_season: List[int]) -> None:
        self.injection_season = injection_season

    def get_dict_from_column(self, col_name: str) -> Dict[dt.date, Union[np.array, int]]:
        self.check_attribute_lbl(col_name)
        return pd.Series(self.attr[col_name], index=self.attr['yyyy-mm-dd']).to_dict()    

    def __mdl_initialize_sets(self) -> None:
        self.mdl.i = pyo.Set(initialize=self.dates)
        self.mdl.j = pyo.Set(initialize=self.injection_idx)
        self.mdl.k = pyo.Set(initialize=self.withdrawal_idx)
        self.mdl.curve_value_type = pyo.Set(initialize=self.curve_value_type)
        self.mdl.bsd_months = pyo.Set(initialize=list(self.bsd_state_to_date.keys()))
    
    def __mdl_initialize_params(self) -> None:
        self.mdl.p = pyo.Param(self.mdl.i, initialize=self.get_dict_from_column('prices'))
        self.mdl.wgv = pyo.Param(self.mdl.i, initialize=self.get_dict_from_column('wgv'))
        self.mdl.ir = pyo.Param(self.mdl.i, initialize=self.get_dict_from_column('ir'))
        self.mdl.wr = pyo.Param(self.mdl.i, initialize=self.get_dict_from_column('wr'))
        self.mdl.m_const = pyo.Param(self.mdl.i, initialize=self.get_dict_from_column('m_const'))
        self.mdl.tab_inj = pyo.Param(self.mdl.i, self.mdl.j, self.mdl.curve_value_type, initialize=self.inj_curve_daily)
        self.mdl.tab_wit = pyo.Param(self.mdl.i, self.mdl.k, self.mdl.curve_value_type, initialize=self.wit_curve_daily)
        self.mdl.bsd_state_to_date = pyo.Param(self.mdl.bsd_months, initialize=self.bsd_state_to_date)

    def __mdl_initialize_vars(self) -> None:
        self.mdl.x = pyo.Var(self.mdl.i, domain=pyo.NonNegativeIntegers, initialize=0, name='x')
        self.mdl.y = pyo.Var(self.mdl.i, domain=pyo.NonNegativeIntegers, initialize=0, name='y')
        self.mdl.z = pyo.Var(self.mdl.i, domain=pyo.NonNegativeIntegers, initialize=0, name='z')

        self.mdl.t_inj = pyo.Var(self.mdl.i, self.mdl.j, domain=pyo.Binary, initialize=0, name='t_inj')
        self.mdl.l_inj = pyo.Var(self.mdl.i, self.mdl.j, domain=pyo.Binary, initialize=0, name='l_inj')
        self.mdl.u_inj = pyo.Var(self.mdl.i, self.mdl.j, domain=pyo.Binary, initialize=0, name='u_inj')

        self.mdl.t_wit = pyo.Var(self.mdl.i, self.mdl.k, domain=pyo.Binary, initialize=0, name='t_wit')
        self.mdl.l_wit = pyo.Var(self.mdl.i, self.mdl.k, domain=pyo.Binary, initialize=0, name='l_wit')
        self.mdl.u_wit = pyo.Var(self.mdl.i, self.mdl.k, domain=pyo.Binary, initialize=0, name='u_wit')

    def __mdl_def_constraints(self) -> None:
        self.mdl.constr_balance = pyo.Constraint(expr = sum(self.mdl.y[i] for i in self.mdl.i) <= self.z0 + sum(self.mdl.x[i] for i in self.mdl.i))

        self.mdl.constr_empty_storage = pyo.ConstraintList()
        if self.empty_storage:
            for date in self.empty_on_dates:
                if (date >= self.date_start) and (date <= self.date_end):
                    self.mdl.constr_empty_storage.add(self.mdl.z[date] == 0)

        self.mdl.constr_capacity = pyo.ConstraintList()
        for i in self.mdl.i:
            self.mdl.constr_capacity.add(self.mdl.z[i] <= self.mdl.wgv[i])

        self.mdl.constr_gs = pyo.ConstraintList()
        for i in self.mdl.i:
            if i == self.date_start:
                self.mdl.constr_gs.add(self.mdl.z[i] == self.z0 + self.mdl.x[i] - self.mdl.y[i])
                continue
            self.mdl.constr_gs.add(self.mdl.z[i] == self.mdl.z[i-self.delta] + self.mdl.x[i] - self.mdl.y[i])

        self.mdl.constr_season = pyo.ConstraintList()
        for i in self.mdl.i:
            if i.month in self.injection_season:
                self.mdl.constr_season.add(self.mdl.y[i] == 0)
            else:
                self.mdl.constr_season.add(self.mdl.x[i] == 0)

        self.mdl.constr_state_to_date = pyo.ConstraintList()
        for i in self.mdl.i:
            for p in self.mdl.bsd_months:
                if i.month == p and i.day == 1:
                    self.mdl.constr_state_to_date.add(self.mdl.z[i] >= self.mdl.bsd_state_to_date[p]*self.mdl.wgv[i])

        self.mdl.constr_inj_low = pyo.ConstraintList()
        for i in self.mdl.i:
            for j in self.mdl.j:
                self.mdl.constr_inj_low.add(self.mdl.tab_inj[(i,j,'lower')]*self.mdl.wgv[i] <= self.mdl.z[i] + self.mdl.m_const[i]*(1-self.mdl.l_inj[i,j]))
                self.mdl.constr_inj_low.add(self.mdl.tab_inj[(i,j,'lower')]*self.mdl.wgv[i] >= self.mdl.z[i] - self.mdl.m_const[i]*self.mdl.l_inj[i,j])
        self.mdl.constr_inj_upp = pyo.ConstraintList()
        for i in self.mdl.i:
            for j in self.mdl.j:
                self.mdl.constr_inj_upp.add(self.mdl.tab_inj[(i,j,'upper')]*self.mdl.wgv[i] >= self.mdl.z[i] - self.mdl.m_const[i]*(1-self.mdl.u_inj[i,j]))
                self.mdl.constr_inj_upp.add(self.mdl.tab_inj[(i,j,'upper')]*self.mdl.wgv[i] <= self.mdl.z[i] + self.mdl.m_const[i]*self.mdl.u_inj[i,j])

        self.mdl.constr_inj_t = pyo.ConstraintList()
        for i in self.mdl.i:
            self.mdl.constr_inj_t.add(sum(self.mdl.t_inj[i,j] for j in self.mdl.j) == 1)
            for j in self.mdl.j:
                self.mdl.constr_inj_t.add(self.mdl.u_inj[i,j] + self.mdl.l_inj[i,j] - 2*self.mdl.t_inj[i,j] >= 0)
                self.mdl.constr_inj_t.add(self.mdl.u_inj[i,j] + self.mdl.l_inj[i,j] - 2*self.mdl.t_inj[i,j] <= 1)
        self.mdl.constr_inj = pyo.ConstraintList()
        for i in self.mdl.i:
            self.mdl.constr_inj.add(self.mdl.x[i] <= self.mdl.ir[i]*sum(self.mdl.tab_inj[(i,j,'portion')]*self.mdl.t_inj[i,j] for j in self.mdl.j))

        self.mdl.constr_wit_low = pyo.ConstraintList()
        for i in self.mdl.i:
            for k in self.mdl.k:
                self.mdl.constr_wit_low.add(self.mdl.tab_wit[(i,k,'lower')]*self.mdl.wgv[i] <= self.mdl.z[i] + self.mdl.m_const[i]*(1-self.mdl.l_wit[i,k]))
                self.mdl.constr_wit_low.add(self.mdl.tab_wit[(i,k,'lower')]*self.mdl.wgv[i] >= self.mdl.z[i] - self.mdl.m_const[i]*self.mdl.l_wit[i,k])
        self.mdl.constr_wit_upp = pyo.ConstraintList()
        for i in self.mdl.i:
            for k in self.mdl.k:
                self.mdl.constr_wit_upp.add(self.mdl.tab_wit[(i,k,'upper')]*self.mdl.wgv[i] >= self.mdl.z[i] - self.mdl.m_const[i]*(1-self.mdl.u_wit[i,k]))
                self.mdl.constr_wit_upp.add(self.mdl.tab_wit[(i,k,'upper')]*self.mdl.wgv[i] <= self.mdl.z[i] + self.mdl.m_const[i]*self.mdl.u_wit[i,k])

        self.mdl.constr_wit_t = pyo.ConstraintList()
        for i in self.mdl.i:
            self.mdl.constr_wit_t.add(sum(self.mdl.t_wit[i,k] for k in self.mdl.k) == 1)
            for k in self.mdl.k:
                self.mdl.constr_wit_t.add(self.mdl.u_wit[i,k] + self.mdl.l_wit[i,k] - 2*self.mdl.t_wit[i,k] >= 0)
                self.mdl.constr_wit_t.add(self.mdl.u_wit[i,k] + self.mdl.l_wit[i,k] - 2*self.mdl.t_wit[i,k] <= 1)
        self.mdl.constr_wit = pyo.ConstraintList()
        for i in self.mdl.i:
            self.mdl.constr_wit.add(self.mdl.y[i] <= self.mdl.wr[i]*sum(self.mdl.tab_wit[(i,k,'portion')]*self.mdl.t_wit[i,k] for k in self.mdl.k))
    
    def create_model(self) -> None:
        self.mdl = pyo.ConcreteModel(name='OptimusGas')
        self.__mdl_initialize_sets()
        self.__mdl_initialize_params()
        self.__mdl_initialize_vars()
        self.mdl.objective = pyo.Objective(
            expr=(sum(self.mdl.y[i]*self.mdl.p[i] for i in self.mdl.i) - sum(self.mdl.x[i]*self.mdl.p[i] for i in self.mdl.i)), 
            sense=pyo.maximize
        )
        self.__mdl_def_constraints()

    def solve_model(
            self, solver_name: Literal['cplex','highs','scip'], time_limit: int = 3600, gap: float = None, 
            stream_solver: bool = True, presolve_highs: Literal['off','choose','on'] = 'choose', presolve_scip: int = None
        ) -> None:
        if not self.mdl:
            self.create_model()
        self.solver_name = solver_name
        if self.solver_name == 'scip':
            self.slvr = pyo.SolverFactory('scip')
            self.slvr.options['lp/threads'] = psutil.cpu_count(logical=True)
            self.slvr.options['limits/time'] = time_limit
            if gap:
                self.slvr.options['limits/gap'] = gap
            if presolve_scip:
                self.slvr.options['presolving/maxrounds'] = presolve_scip

            self.results = self.slvr.solve(self.mdl, tee=stream_solver)
            self.termination_condition = self.results.solver.termination_condition
            if (self.termination_condition == pyo.TerminationCondition.optimal) or (self.results.solver.primal_bound is not None):
                self.__extract_values_from_model()
                self.objective = self.mdl.objective()
                self.best_feasible_objective = self.results.solver.primal_bound
                self.best_objective_bound = self.results.solver.dual_bound
                self.gap = (self.best_objective_bound - self.best_feasible_objective) / self.best_feasible_objective
                self.solved=True
                print('\nTermination condition: ', self.termination_condition)
                print('Solver status: ', self.results.solver.status)
                print('Solver message: ', self.results.solver.message)
                print('Best feasible objective: ', self.best_feasible_objective)
                print('Best objective bound: ', self.best_objective_bound)
                print('Gap: ', self.gap)
                print(f'Objective: {self.objective}\n')
            else:
                raise Exception(f"Couldn't find any feasible solution.\nTermination condition: {self.termination_condition}")
        else:
            if self.solver_name == 'cplex':
                self.slvr = appsi.solvers.Cplex()
                self.slvr.cplex_options = {'threads': psutil.cpu_count(logical=True)}
            elif self.solver_name == 'highs':
                self.slvr = appsi.solvers.Highs()
                self.slvr.highs_options = {'threads': psutil.cpu_count(logical=True), 'presolve': presolve_highs}
            else:
                raise Exception(f"Only two following solvers are available: cplex, highs.")

            self.slvr.config.time_limit = time_limit
            if gap:
                self.slvr.config.mip_gap = gap
            self.slvr.config.stream_solver = stream_solver
            self.slvr.config.load_solution = False

            self.results = self.slvr.solve(self.mdl)
            self.termination_condition = self.results.termination_condition            
            if (self.termination_condition == appsi.base.TerminationCondition.optimal) or (self.results.best_feasible_objective is not None):
                self.results.solution_loader.load_vars()
            if (self.termination_condition == appsi.base.TerminationCondition.optimal) or (self.results.best_feasible_objective is not None):
                self.__extract_values_from_model()
                self.objective = self.mdl.objective()
                self.best_feasible_objective = self.results.best_feasible_objective
                self.best_objective_bound = self.results.best_objective_bound
                self.gap = (self.best_objective_bound - self.best_feasible_objective) / self.best_feasible_objective
                self.solved = True
                print('\nTermination condition: ', self.termination_condition)
                print('Best feasible objective: ', self.best_feasible_objective)
                print('Best objective bound: ', self.best_objective_bound)
                print('Gap: ', self.gap)
                print(f'Objective: {self.objective}\n')
            else:
                raise Exception(f"Couldn't find any feasible solution.\nTermination condition: {self.termination_condition}")
        
    def __extract_values_from_model(self) -> None:
        self.mdl.compute_statistics()
        self.statistics = self.mdl.statistics

        self.res_injection = self.mdl.x.extract_values()
        self.res_withdrawal = self.mdl.y.extract_values()
        self.res_gs_state = self.mdl.z.extract_values()
        self.res_operations = {key: self.res_injection[key] - self.res_withdrawal[key] for key in self.dates}
        
        ir = self.mdl.ir.extract_values()
        wr = self.mdl.wr.extract_values()
        t_inj = self.mdl.t_inj.extract_values()
        t_wit = self.mdl.t_wit.extract_values()
        self.max_operations = {}
        for i in self.dates:
            if i.month in self.injection_season:
                self.max_operations[i] = ir[i]*sum(self.inj_curve_daily[(i,j,'portion')]*t_inj[i,j] for j in list(self.mdl.j))
            else:
                self.max_operations[i] = -wr[i]*sum(self.wit_curve_daily[(i,k,'portion')]*t_wit[i,k] for k in list(self.mdl.k))
        
        self.daily_export = pd.DataFrame(
            list(zip(
                list(self.attr['year']),list(self.attr['month']),list(self.res_operations.values()),
                list(self.res_gs_state.values()),list(self.max_operations.values()),list(self.attr['wgv']))),
            index=self.dates,
            columns=['Rok','M','W/I','Stav','Max C', 'WGV'])
        daily_export_agg = self.daily_export.groupby(['Rok','M']).agg(
            w_i=('W/I','sum'), year=('Rok', 'min'), month=('M', 'min'), wgv=('WGV', 'min')
        )
        self.daily_export['Stav %'] = self.daily_export['Stav']/self.daily_export['WGV']

        gs_state = []
        for i in range(0,len(daily_export_agg)):
            if i == 0:
                gs_state.append(self.z0 + daily_export_agg.w_i.values[i])
                continue
            gs_state.append(gs_state[i-1] + daily_export_agg.w_i.values[i])
        self.monthly_export = pd.DataFrame(    
            list(zip(
                daily_export_agg.year.values, daily_export_agg.month.values, daily_export_agg.w_i.values, gs_state, daily_export_agg.wgv
            )),
            columns=['Rok','M','W/I','Stav','WGV']
        )
        self.monthly_export['Stav %'] = self.monthly_export['Stav']/self.monthly_export['WGV']
    
    def graphs(self) -> None:
        self.fig = po.Figure()
        self.fig.add_trace(po.Scatter(x=self.dates, y=list(self.max_operations.values()), name='Max. operations', line_color='#ffa600', mode='lines'))
        self.fig.add_trace(po.Scatter(x=self.dates, y=list(self.res_operations.values()), name='Operations', fill='tozeroy', line_color='#74d576', mode='lines'))
        self.fig.add_trace(po.Scatter(x=self.dates, y=list(self.res_gs_state.values()), name='GS state', fill='tozeroy', line_color='#34dbeb', yaxis = 'y2'))
        self.fig.update_layout(
            title = f'{self.name} gas storage optimization<br><sup>Solver: {self.solver_name}</sup>',
            xaxis_title = 'Date',
            yaxis = dict(
                title = 'Operations [MWh/day]'),
            yaxis2 = dict(
                title = "GS state [MWh]",
                side = 'right',
                overlaying = 'y',
                titlefont = dict(color='#34dbeb'),
                tickfont = dict(color='#34dbeb')),
            legend = dict(
                orientation = "v",
                x = 1.06,
                xanchor = 'left',
                y = 1)
        )
        self.fig.update_xaxes(fixedrange=False)
        self.fig.update_yaxes(zeroline=True, zerolinewidth=3, zerolinecolor='grey')
        self.fig.show()
        self.__export_graph_to_html()
    
    def __export_graph_to_html(self):
        self.fig.write_html(f'export/{self.id}_graph.html')

    def export_to_xlsx(self) -> None:
        with pd.ExcelWriter(f'export/{self.name}_export.xlsx', mode='w', engine='xlsxwriter') as writer:
            self.daily_export[['Rok','M','W/I','Stav','Stav %','Max C']].to_excel(writer, sheet_name='data_daily', index=True, index_label='Datum')
            self.monthly_export[['Rok','M','W/I','Stav','Stav %']].to_excel(writer, sheet_name='data_monthly', index=False)
            percent_format = writer.book.add_format({"num_format": "0%"})
            writer.sheets['data_daily'].set_column(5, 5, None, percent_format)
            writer.sheets['data_daily'].set_column(0, 0, 10)
            writer.sheets['data_monthly'].set_column(4, 4, None, percent_format)
            print(f'Results exported to {self.id}_export.xlsx')

    @classmethod
    def export_all_storages(cls) -> None:
        if not cls._instances:
            raise Exception('No objects initialized yet.')
        for self in cls._instances:
            if not self.solved:
                raise Exception("One of the objects wasn't solved yet")
        date_min = min(cls._instances[0].dates)
        date_max = max(cls._instances[0].dates)
        for self in cls._instances:
            if min(self.dates) < date_min:
                date_min = min(self.dates)
            if max(self.dates) > date_max:
                date_max = max(self.dates)

        cls._dates = [date_min + dt.timedelta(days=i) for i in range(0,(date_max-date_min).days+1)]
        cls._total_operations = {key: 0 for key in cls._dates}
        cls._total_max_operations = {key: 0 for key in cls._dates}
        cls._total_gs_state = {key: 0 for key in cls._dates}
        cls._total_wgv = {key: 0 for key in cls._dates}
        for self in cls._instances:
            wgv_dict = self.get_dict_from_column('wgv')
            for d in cls._dates:
                if d in self.res_operations.keys():
                    cls._total_operations[d] += self.res_operations[d]
                if d in self.max_operations.keys():
                    cls._total_max_operations[d] += self.max_operations[d]
                if d in self.res_gs_state.keys():
                    cls._total_gs_state[d] += self.res_gs_state[d]
                if d in wgv_dict.keys():
                    cls._total_wgv[d] += wgv_dict[d]
        cls._total_data = pd.DataFrame(
            list(zip(
                list(cls._total_operations.values()),list(cls._total_gs_state.values()),
                list(cls._total_max_operations.values()),list(cls._total_wgv.values()))),
            index=pd.DatetimeIndex(cls._dates),
            columns=['W/I','Stav','Max C', 'WGV'])
        cls._total_data['yyyy-mm-dd'] = cls._total_data.index.date
        cls._total_data['Rok'] = cls._total_data.index.year
        cls._total_data['M'] = cls._total_data.index.month
        cls._total_data['Stav %'] = cls._total_data['Stav']/cls._total_data['WGV']

        cls.__to_xlsx()
        cls.__graph()

    @classmethod
    def __to_xlsx(cls) -> None:
        cls._total_daily_export = pd.DataFrame(
            cls._total_data[['Rok','M','W/I','Stav', 'Stav %','Max C', 'WGV']],
            index=cls._dates)
        total_daily_export_agg = cls._total_daily_export.groupby(['Rok','M']).agg(
            w_i=('W/I','sum'), year=('Rok', 'min'), month=('M', 'min'), wgv=('WGV', 'min')
        )
        for self in cls._instances:
            cls._total_daily_export[f'{self.name} Stav'] = self.daily_export['Stav']
            cls._total_daily_export[f'{self.name} W/I'] = self.daily_export['W/I']
            cls._total_daily_export[f'{self.name} Max C'] = self.daily_export['Max C']

        gs_state_monthly = []
        z0 = 0
        for self in cls._instances:
            if min(self.dates) == min(cls._dates):
                z0 += self.z0
        for i in range(0,len(total_daily_export_agg)):
            if i == 0:
                gs_state_monthly.append(z0 + total_daily_export_agg.w_i.values[i])
                continue
            gs_state_monthly.append(gs_state_monthly[i-1] + total_daily_export_agg.w_i.values[i])

        cls._total_monthly_export = pd.DataFrame(    
            list(zip(
                total_daily_export_agg.year.values, total_daily_export_agg.month.values, total_daily_export_agg.w_i.values, gs_state_monthly, total_daily_export_agg.wgv
            )),
            columns=['Rok','M','W/I','Stav','WGV']
        )
        cls._total_monthly_export['Stav %'] = cls._total_monthly_export['Stav']/cls._total_monthly_export['WGV']

        with pd.ExcelWriter('export/total_export.xlsx', mode='w', engine='xlsxwriter') as writer:
            cls._total_daily_export[
                ['Rok','M','W/I',*[f'{self.name} W/I' for self in cls._instances],'Stav %','Stav',*[f'{self.name} Stav' for self in cls._instances],
                 'Max C',*[f'{self.name} Max C' for self in cls._instances]]
            ].to_excel(writer, sheet_name='data_daily', index=True, index_label='Datum')
            cls._total_monthly_export[['Rok','M','W/I','Stav %','Stav']].to_excel(writer, sheet_name='data_monthly', index=False)
            writer.sheets['data_daily'].set_column(0, 0, 10)
            print('Results exported to total_export.xlsx')
        for self in cls._instances:
            self.export_to_xlsx()

    @classmethod
    def __graph(cls):
        cls._fig = po.Figure()
        cls._fig.add_trace(po.Scatter(x=cls._dates, y=list(cls._total_max_operations.values()), name='Max. operations', line_color='#ffa600', mode='lines'))
        cls._fig.add_trace(po.Scatter(x=cls._dates, y=list(cls._total_operations.values()), name='Operations', fill='tozeroy', line_color='#74d576', mode='lines'))
        cls._fig.add_trace(po.Scatter(x=cls._dates, y=list(cls._total_gs_state.values()), name='GS state', fill='tozeroy', line_color='#34dbeb', yaxis = 'y2'))
        cls._fig.update_layout(
            title = f'Total gas storage optimization',
            xaxis_title = 'Date',
            yaxis = dict(
                title = 'Operations [MWh/day]'),
            yaxis2 = dict(
                title = "GS state [MWh]",
                side = 'right',
                overlaying = 'y',
                titlefont = dict(color='#34dbeb'),
                tickfont = dict(color='#34dbeb')),
            legend = dict(
                orientation = "v",
                x = 1.06,
                xanchor = 'left',
                y = 1)
        )
        cls._fig.update_xaxes(fixedrange=False)
        cls._fig.update_yaxes(zeroline=True, zerolinewidth=3, zerolinecolor='grey')
        cls._fig.show()
        cls._fig.write_html('export/total_graph.html')
        for self in cls._instances:
            self.graphs()

# %% [markdown]
#   [linear] <lc855>: <i35784>[I] (+0) -<i36636>[I] (+0) +<i37490>[I] (+0) == 2078317;
# ;
# violation: left hand side is violated by 2078317
# all 1 solutions given by solution candidate storage are infeasible
#
#   [linear] <lc1097>: <i14996>[I] (+0) >= 10853.9895;
# ;
# violation: left hand side is violated by 10853.9895
# all 1 solutions given by solution candidate storage are infeasible
#
#   [linear] <lc1097>: <i14996>[I] (+0) >= 10853.95;
# ;
# violation: left hand side is violated by 10853.95
# all 1 solutions given by solution candidate storage are infeasible

# %% [markdown]
# Object initialization

# %%
def initialize_storage(name):
    if name == 'RWE':
        date_start_rwe = dt.date(2023, 12, 1)
        date_end_rwe = dt.date(2026, 3, 31)
        storage_rwe = GasStorage('RWE', date_start_rwe, date_end_rwe)

        storage_rwe.load_prices('prices.xlsx')
        storage_rwe.load_attribute('wgv', 2078317.01, date_start_rwe, dt.date(2024, 3, 31))
        storage_rwe.load_attribute('wgv', 1466800, dt.date(2024, 4, 1), dt.date(2025, 3, 31))
        storage_rwe.load_attribute('wgv', 300000, dt.date(2025, 4, 1), date_end_rwe)
        storage_rwe.load_attribute('wr', 31863.111, date_start_rwe, dt.date(2024, 3, 31))
        storage_rwe.load_attribute('wr', 21549, dt.date(2024, 4, 1), dt.date(2025, 3, 31))
        storage_rwe.load_attribute('wr', 4200, dt.date(2025, 4, 1), date_end_rwe)
        storage_rwe.load_attribute('ir', 23648.928, date_start_rwe, dt.date(2024, 3, 31))
        storage_rwe.load_attribute('ir', 16395, dt.date(2024, 4, 1), dt.date(2025, 3, 31))
        storage_rwe.load_attribute('ir', 3000, dt.date(2025, 4, 1), date_end_rwe)
        inj_curve = np.array([[0,8,16,48,75,82,91,96],
                            [8,16,48,75,82,91,96,100],
                            [50,75,100,93,80,65,55,20]])/100
        storage_rwe.load_attribute('inj_curve', inj_curve, date_start_rwe, date_end_rwe)
        wit_curve = np.array([[0,3,15,35,72,85],
                            [3,15,35,72,85,100],
                            [18,53,78,100,73,40]])/100
        storage_rwe.load_attribute('wit_curve', wit_curve, date_start_rwe, date_end_rwe)

        storage_rwe.set_initial_state(2078317)
        storage_rwe.set_dates_to_empty_storage([dt.date(2025, 3, 31), date_end_rwe])
        storage_rwe.set_injection_season([4,5,6,7,8,9])
        storage_rwe.set_state_to_date({5: 0.05, 7: 0.3, 9: 0.6, 11: 0.9})

        storage_rwe.create_model()
        return storage_rwe

    if name == 'MND':
        date_start_mnd = dt.date(2023, 12, 1)
        date_end_mnd = dt.date(2024, 3, 31)
        storage_mnd = GasStorage('MND', date_start_mnd, date_end_mnd)

        storage_mnd.load_prices('prices.xlsx')
        storage_mnd.load_attribute('wgv', 55000, date_start_mnd, date_end_mnd)
        storage_mnd.load_attribute('wr', 917, date_start_mnd, date_end_mnd)
        storage_mnd.load_attribute('ir', 612, date_start_mnd, date_end_mnd)
        inj_curve = np.array([[0, 70], 
                            [70, 100], 
                            [100, 50]])/100
        storage_mnd.load_attribute('inj_curve', inj_curve, date_start_mnd, date_end_mnd)
        wit_curve = np.array([[0, 40], 
                            [40, 100], 
                            [60, 100]])/100
        storage_mnd.load_attribute('wit_curve', wit_curve, date_start_mnd, date_end_mnd)

        storage_mnd.set_initial_state(55000)
        storage_mnd.set_dates_to_empty_storage([date_end_mnd])
        storage_mnd.set_injection_season([4,5,6,7,8,9])
        storage_mnd.set_state_to_date({5: 0.05, 7: 0.3, 9: 0.6, 11: 0.9})

        storage_mnd.create_model()
        return storage_mnd

    if name == 'MGS':
        date_start_mgs = dt.date(2024, 4, 1)
        date_end_mgs = dt.date(2025, 3, 31)
        storage_mgs = GasStorage('MGS', date_start_mgs, date_end_mgs)

        storage_mgs.load_prices('prices.xlsx')
        storage_mgs.load_attribute('wgv', 217079, date_start_mgs, date_end_mgs)
        storage_mgs.load_attribute('wr', 3635, date_start_mgs, date_end_mgs)
        storage_mgs.load_attribute('ir', 2181, date_start_mgs, date_end_mgs)
        inj_curve = np.array([[0,81,84,88,92,96], 
                            [81,84,88,92,96,100], 
                            [100,96.682,92.258,87.834,83.41,78.956]])/100
        storage_mgs.load_attribute('inj_curve', inj_curve, date_start_mgs, date_end_mgs)
        wit_curve = np.array([[0,4,8,12,16,20,22], 
                            [4,8,12,16,20,22,100], 
                            [49.854,58.971,68.089,77.206,84.044,95.441,100]])/100
        storage_mgs.load_attribute('wit_curve', wit_curve, date_start_mgs, date_end_mgs)

        storage_mgs.set_initial_state(0)
        storage_mgs.set_dates_to_empty_storage([date_end_mgs])
        storage_mgs.set_injection_season([4,5,6,7,8,9])
        storage_mgs.set_state_to_date({5: 0.05, 7: 0.3, 9: 0.6, 11: 0.9})

        storage_mgs.create_model()
        return storage_mgs

# %%
storage_mgs = initialize_storage('MGS')
storage_mnd = initialize_storage('MND')
storage_rwe = initialize_storage('RWE')

# %% [markdown]
# Solve and export

# %%
storage_mgs.solve_model(solver_name='scip', stream_solver=True)
# storage_mnd.solve_model(solver_name='cplex', stream_solver=False)
# # storage_rwe.solve_model(solver_name='highs', time_limit=300, gap=0.0005, presolve='off')
# storage_rwe.solve_model(solver_name='cplex', time_limit=3600, gap=0.0005)
# Out:
# SCIP version 8.0.4 [precision: 8 byte] [memory: block] [mode: optimized] [LP solver: Soplex 6.0.4] [GitHash: a8e51afd1e]
# Copyright (c) 2002-2023 Zuse Institute Berlin (ZIB)
#
# External libraries:
#   Soplex 6.0.4         Linear Programming Solver developed at Zuse Institute Berlin (soplex.zib.de) [GitHash: 950b1658]
#   CppAD 20180000.0     Algorithmic Differentiation of C++ algorithms developed by B. Bell (github.com/coin-or/CppAD)
#   ZLIB 1.2.11          General purpose compression library by J. Gailly and M. Adler (zlib.net)
#   GMP 6.2.1            GNU Multiple Precision Arithmetic Library developed by T. Granlund (gmplib.org)
#   ZIMPL 3.5.3          Zuse Institute Mathematical Programming Language developed by T. Koch (zimpl.zib.de)
#   AMPL/MP 4e2d45c4     AMPL .nl file reader library (github.com/ampl/mp)
#   PaPILO 2.1.3         parallel presolve for integer and linear optimization (github.com/scipopt/papilo) [GitHash: cec22d9]
#   bliss 0.77           Computing Graph Automorphism Groups by T. Junttila and P. Kaski (www.tcs.hut.fi/Software/bliss/)
#   Ipopt 3.13.2         Interior Point Optimizer developed by A. Waechter et.al. (github.com/coin-or/Ipopt)
#
# reading user parameter file <scip.set>
# ===========================
#
# limits/time = 3600
# lp/threads = 12
#
# read problem </tmp/tmpkryx9ll_.pyomo.nl>
# ============
#
# original problem has 15330 variables (14235 bin, 1095 int, 0 impl, 0 cont) and 31031 constraints
#
# solve problem
# =============
#
#   [linear] <lc1097>: <i14996>[I] (+0) >= 10854;
# ;
# violation: left hand side is violated by 10854
# all 1 solutions given by solution candidate storage are infeasible
#
# presolving:
# (round 1, fast)       503 del vars, 2810 del conss, 0 add conss, 1224 chg bounds, 24067 chg sides, 22072 chg coeffs, 0 upgd conss, 0 impls, 737 clqs
# (round 2, fast)       3441 del vars, 7981 del conss, 0 add conss, 4137 chg bounds, 26401 chg sides, 25292 chg coeffs, 0 upgd conss, 0 impls, 1116 clqs
# (round 3, fast)       4096 del vars, 9318 del conss, 0 add conss, 4696 chg bounds, 26728 chg sides, 25666 chg coeffs, 0 upgd conss, 0 impls, 1097 clqs
# (round 4, fast)       4590 del vars, 10278 del conss, 0 add conss, 5217 chg bounds, 27138 chg sides, 26374 chg coeffs, 0 upgd conss, 0 impls, 1093 clqs
# (round 5, fast)       4917 del vars, 10895 del conss, 0 add conss, 5561 chg bounds, 27466 chg sides, 26810 chg coeffs, 0 upgd conss, 1 impls, 1102 clqs
# (round 6, fast)       5222 del vars, 11483 del conss, 0 add conss, 5895 chg bounds, 27780 chg sides, 27353 chg coeffs, 0 upgd conss, 1 impls, 1118 clqs
# (round 7, fast)       5466 del vars, 11947 del conss, 0 add conss, 6160 chg bounds, 28035 chg sides, 27704 chg coeffs, 0 upgd conss, 1 impls, 1120 clqs
# (round 8, fast)       5697 del vars, 12392 del conss, 0 add conss, 6418 chg bounds, 28283 chg sides, 28134 chg coeffs, 0 upgd conss, 1 impls, 1125 clqs
# (round 9, fast)       5857 del vars, 12678 del conss, 0 add conss, 6584 chg bounds, 28479 chg sides, 28436 chg coeffs, 0 upgd conss, 1 impls, 1120 clqs
# (round 10, fast)       5995 del vars, 12929 del conss, 0 add conss, 6728 chg bounds, 28634 chg sides, 28738 chg coeffs, 0 upgd conss, 1 impls, 1133 clqs
# (round 11, fast)       6104 del vars, 13137 del conss, 0 add conss, 6838 chg bounds, 28734 chg sides, 28873 chg coeffs, 0 upgd conss, 1 impls, 1137 clqs
# (round 12, fast)       6216 del vars, 13340 del conss, 0 add conss, 6959 chg bounds, 28863 chg sides, 29121 chg coeffs, 0 upgd conss, 1 impls, 1141 clqs
# (round 13, fast)       6302 del vars, 13501 del conss, 0 add conss, 7045 chg bounds, 28942 chg sides, 29227 chg coeffs, 0 upgd conss, 1 impls, 1145 clqs
# (round 14, fast)       6395 del vars, 13668 del conss, 0 add conss, 7143 chg bounds, 29044 chg sides, 29419 chg coeffs, 0 upgd conss, 1 impls, 1139 clqs
# (round 15, fast)       6447 del vars, 13765 del conss, 0 add conss, 7192 chg bounds, 29093 chg sides, 29484 chg coeffs, 0 upgd conss, 1 impls, 1142 clqs
# (round 16, fast)       6513 del vars, 13886 del conss, 0 add conss, 7262 chg bounds, 29172 chg sides, 29637 chg coeffs, 0 upgd conss, 1 impls, 1145 clqs
# (round 17, fast)       6551 del vars, 13959 del conss, 0 add conss, 7303 chg bounds, 29224 chg sides, 29715 chg coeffs, 0 upgd conss, 1 impls, 1151 clqs
# (round 18, fast)       6600 del vars, 14046 del conss, 0 add conss, 7358 chg bounds, 29299 chg sides, 29868 chg coeffs, 0 upgd conss, 1 impls, 1146 clqs
# (round 19, fast)       6635 del vars, 14112 del conss, 0 add conss, 7397 chg bounds, 29349 chg sides, 29944 chg coeffs, 0 upgd conss, 1 impls, 1155 clqs
# (round 20, fast)       6675 del vars, 14182 del conss, 0 add conss, 7442 chg bounds, 29429 chg sides, 30110 chg coeffs, 0 upgd conss, 1 impls, 1152 clqs
# (round 21, fast)       6698 del vars, 14231 del conss, 0 add conss, 7469 chg bounds, 29468 chg sides, 30176 chg coeffs, 0 upgd conss, 1 impls, 1159 clqs
# (round 22, fast)       6737 del vars, 14297 del conss, 0 add conss, 7513 chg bounds, 29544 chg sides, 30331 chg coeffs, 0 upgd conss, 1 impls, 1160 clqs
# (round 23, fast)       6765 del vars, 14352 del conss, 0 add conss, 7542 chg bounds, 29574 chg sides, 30379 chg coeffs, 0 upgd conss, 1 impls, 1158 clqs
# (round 24, fast)       6792 del vars, 14400 del conss, 0 add conss, 7573 chg bounds, 29629 chg sides, 30487 chg coeffs, 0 upgd conss, 1 impls, 1160 clqs
# (round 25, fast)       6826 del vars, 14457 del conss, 0 add conss, 7606 chg bounds, 29673 chg sides, 30571 chg coeffs, 0 upgd conss, 1 impls, 1156 clqs
# (round 26, fast)       6858 del vars, 14515 del conss, 0 add conss, 7639 chg bounds, 29725 chg sides, 30669 chg coeffs, 0 upgd conss, 1 impls, 1164 clqs
# (round 27, fast)       6871 del vars, 14540 del conss, 0 add conss, 7655 chg bounds, 29754 chg sides, 30729 chg coeffs, 0 upgd conss, 1 impls, 1165 clqs
# (round 28, fast)       6892 del vars, 14573 del conss, 0 add conss, 7677 chg bounds, 29796 chg sides, 30812 chg coeffs, 0 upgd conss, 1 impls, 1165 clqs
# (round 29, fast)       6907 del vars, 14604 del conss, 0 add conss, 7694 chg bounds, 29828 chg sides, 30877 chg coeffs, 0 upgd conss, 1 impls, 1165 clqs
# (round 30, fast)       6924 del vars, 14633 del conss, 0 add conss, 7712 chg bounds, 29859 chg sides, 30939 chg coeffs, 0 upgd conss, 1 impls, 1166 clqs
# (round 31, fast)       6939 del vars, 14660 del conss, 0 add conss, 7730 chg bounds, 29888 chg sides, 30998 chg coeffs, 0 upgd conss, 1 impls, 1162 clqs
# (round 32, fast)       6957 del vars, 14693 del conss, 0 add conss, 7749 chg bounds, 29923 chg sides, 31067 chg coeffs, 0 upgd conss, 1 impls, 1164 clqs
# (round 33, fast)       6968 del vars, 14715 del conss, 0 add conss, 7762 chg bounds, 29929 chg sides, 31074 chg coeffs, 0 upgd conss, 1 impls, 1166 clqs
# (round 34, fast)       6974 del vars, 14727 del conss, 0 add conss, 7773 chg bounds, 29961 chg sides, 31142 chg coeffs, 0 upgd conss, 1 impls, 1166 clqs
# (round 35, fast)       6980 del vars, 14739 del conss, 0 add conss, 7781 chg bounds, 29966 chg sides, 31150 chg coeffs, 0 upgd conss, 1 impls, 1166 clqs
#    (0.2s) running MILP presolver
#    (2.1s) MILP presolver (41 rounds): 1744 aggregations, 1793 fixings, 470 bound changes
# (round 36, medium)     10517 del vars, 31031 del conss, 9708 add conss, 8252 chg bounds, 29971 chg sides, 31161 chg coeffs, 0 upgd conss, 1 impls, 391 clqs
# (round 37, fast)       10517 del vars, 31031 del conss, 9708 add conss, 8252 chg bounds, 29988 chg sides, 31197 chg coeffs, 0 upgd conss, 1 impls, 1003 clqs
# (round 38, exhaustive) 10517 del vars, 31031 del conss, 9708 add conss, 8252 chg bounds, 29988 chg sides, 31197 chg coeffs, 9063 upgd conss, 1 impls, 1003 clqs
# (round 39, medium)     11084 del vars, 32508 del conss, 11314 add conss, 8252 chg bounds, 30030 chg sides, 31244 chg coeffs, 9063 upgd conss, 5860 impls, 9738 clqs
# (round 40, medium)     11084 del vars, 33571 del conss, 11314 add conss, 8252 chg bounds, 30030 chg sides, 31244 chg coeffs, 9063 upgd conss, 5860 impls, 9739 clqs
# (round 41, exhaustive) 11084 del vars, 36499 del conss, 12686 add conss, 8252 chg bounds, 30030 chg sides, 31244 chg coeffs, 9063 upgd conss, 5860 impls, 9739 clqs
# (round 42, medium)     11088 del vars, 36499 del conss, 12686 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9063 upgd conss, 5860 impls, 9727 clqs
# (round 43, exhaustive) 11088 del vars, 36505 del conss, 12692 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9063 upgd conss, 5860 impls, 9727 clqs
# (round 44, exhaustive) 11113 del vars, 36505 del conss, 12692 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 35526 impls, 77387 clqs
# (round 45, medium)     11113 del vars, 36555 del conss, 12692 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 35530 impls, 77391 clqs
# (round 46, exhaustive) 11113 del vars, 36559 del conss, 12696 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 35530 impls, 77391 clqs
# (round 47, exhaustive) 11138 del vars, 36559 del conss, 12696 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 39788 impls, 77268 clqs
# (round 48, medium)     11138 del vars, 36609 del conss, 12696 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 39788 impls, 77268 clqs
# (round 49, exhaustive) 11138 del vars, 36612 del conss, 12699 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 39788 impls, 77268 clqs
# (round 50, exhaustive) 11163 del vars, 36612 del conss, 12699 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 44538 impls, 77216 clqs
# (round 51, medium)     11163 del vars, 36662 del conss, 12699 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 44538 impls, 77216 clqs
# (round 52, exhaustive) 11163 del vars, 36671 del conss, 12708 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 44538 impls, 77216 clqs
# (round 53, exhaustive) 11188 del vars, 36671 del conss, 12708 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 50303 impls, 77348 clqs
# (round 54, medium)     11188 del vars, 36721 del conss, 12708 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 50303 impls, 77348 clqs
# (round 55, exhaustive) 11213 del vars, 36722 del conss, 12709 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 54292 impls, 77331 clqs
# (round 56, medium)     11213 del vars, 36772 del conss, 12709 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 54292 impls, 77332 clqs
# (round 57, exhaustive) 11213 del vars, 36777 del conss, 12714 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 54292 impls, 77332 clqs
# (round 58, exhaustive) 11238 del vars, 36777 del conss, 12714 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 58538 impls, 77360 clqs
# (round 59, medium)     11238 del vars, 36827 del conss, 12714 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 58538 impls, 77360 clqs
# (round 60, exhaustive) 11263 del vars, 36829 del conss, 12716 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 71869 impls, 77214 clqs
# (round 61, medium)     11263 del vars, 36879 del conss, 12716 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 71869 impls, 77216 clqs
# (round 62, exhaustive) 11263 del vars, 36890 del conss, 12727 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 71869 impls, 77216 clqs
# (round 63, exhaustive) 11288 del vars, 36890 del conss, 12727 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 77378 impls, 76965 clqs
# (round 64, medium)     11288 del vars, 36940 del conss, 12727 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 77378 impls, 76965 clqs
# (round 65, exhaustive) 11288 del vars, 36943 del conss, 12730 add conss, 8252 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 77378 impls, 76965 clqs
# (round 66, exhaustive) 11313 del vars, 36943 del conss, 12730 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 81981 impls, 77013 clqs
# (round 67, medium)     11313 del vars, 36993 del conss, 12730 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 81981 impls, 77013 clqs
# (round 68, exhaustive) 11338 del vars, 36993 del conss, 12730 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 86549 impls, 77059 clqs
# (round 69, medium)     11338 del vars, 37043 del conss, 12730 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 86549 impls, 77059 clqs
# (round 70, exhaustive) 11363 del vars, 37044 del conss, 12731 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 90960 impls, 77060 clqs
# (round 71, medium)     11363 del vars, 37094 del conss, 12731 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 90960 impls, 77061 clqs
# (round 72, exhaustive) 11388 del vars, 37094 del conss, 12731 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 97470 impls, 77192 clqs
# (round 73, medium)     11388 del vars, 37144 del conss, 12731 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 97470 impls, 77192 clqs
# (round 74, exhaustive) 11413 del vars, 37146 del conss, 12733 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 104170 impls, 77176 clqs
# (round 75, medium)     11413 del vars, 37196 del conss, 12733 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 104170 impls, 77178 clqs
# (round 76, exhaustive) 11413 del vars, 37199 del conss, 12736 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 104170 impls, 77178 clqs
# (round 77, exhaustive) 11438 del vars, 37199 del conss, 12736 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 117921 impls, 77153 clqs
# (round 78, medium)     11438 del vars, 37249 del conss, 12736 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 117921 impls, 77153 clqs
# (round 79, exhaustive) 11438 del vars, 37254 del conss, 12741 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 117921 impls, 77153 clqs
# (round 80, exhaustive) 11463 del vars, 37254 del conss, 12741 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 123824 impls, 77203 clqs
# (round 81, medium)     11463 del vars, 37304 del conss, 12741 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 123824 impls, 77203 clqs
# (round 82, exhaustive) 11463 del vars, 37309 del conss, 12746 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 123824 impls, 77203 clqs
# (round 83, exhaustive) 11488 del vars, 37309 del conss, 12746 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 128862 impls, 76979 clqs
# (round 84, medium)     11488 del vars, 37359 del conss, 12746 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 128862 impls, 76979 clqs
# (round 85, exhaustive) 11488 del vars, 37362 del conss, 12749 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 128862 impls, 76979 clqs
# (round 86, exhaustive) 11513 del vars, 37362 del conss, 12749 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 133568 impls, 76979 clqs
# (round 87, medium)     11513 del vars, 37412 del conss, 12749 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 133568 impls, 76979 clqs
# (round 88, exhaustive) 11513 del vars, 37417 del conss, 12754 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 133568 impls, 76979 clqs
# (round 89, exhaustive) 11538 del vars, 37417 del conss, 12754 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 138131 impls, 77123 clqs
# (round 90, medium)     11538 del vars, 37467 del conss, 12754 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 138131 impls, 77123 clqs
# (round 91, exhaustive) 11563 del vars, 37467 del conss, 12754 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 143160 impls, 77054 clqs
# (round 92, medium)     11563 del vars, 37517 del conss, 12754 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 143160 impls, 77054 clqs
# (round 93, exhaustive) 11563 del vars, 37521 del conss, 12758 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 143160 impls, 77054 clqs
# (round 94, exhaustive) 11588 del vars, 37521 del conss, 12758 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 148637 impls, 77080 clqs
# (round 95, medium)     11588 del vars, 37571 del conss, 12758 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 148637 impls, 77080 clqs
#    (5.3s) probing: 1000/3840 (26.0%) - 0 fixings, 516 aggregations, 1060772 implications, 1 bound changes
# (round 96, exhaustive) 11613 del vars, 37573 del conss, 12760 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 168582 impls, 77125 clqs
# (round 97, medium)     11613 del vars, 37623 del conss, 12760 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 168582 impls, 77127 clqs
# (round 98, exhaustive) 11613 del vars, 37632 del conss, 12769 add conss, 8253 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 168582 impls, 77127 clqs
# (round 99, exhaustive) 11638 del vars, 37632 del conss, 12769 add conss, 8256 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 204606 impls, 77388 clqs
# (round 100, medium)     11638 del vars, 37682 del conss, 12769 add conss, 8256 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 204606 impls, 77388 clqs
# (round 101, exhaustive) 11638 del vars, 37690 del conss, 12777 add conss, 8256 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 204606 impls, 77388 clqs
# (round 102, exhaustive) 11663 del vars, 37690 del conss, 12777 add conss, 8256 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 213763 impls, 76821 clqs
# (round 103, medium)     11663 del vars, 37740 del conss, 12777 add conss, 8256 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 213763 impls, 76821 clqs
# (round 104, exhaustive) 11663 del vars, 37749 del conss, 12786 add conss, 8256 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 213763 impls, 76821 clqs
# (round 105, exhaustive) 11688 del vars, 37749 del conss, 12786 add conss, 8256 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 218874 impls, 76996 clqs
# (round 106, medium)     11688 del vars, 37799 del conss, 12786 add conss, 8256 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 218874 impls, 76996 clqs
# (round 107, exhaustive) 11688 del vars, 37808 del conss, 12795 add conss, 8256 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 218874 impls, 76996 clqs
#    (8.8s) probing: 2000/3840 (52.1%) - 1 fixings, 612 aggregations, 1967709 implications, 20 bound changes
#    (13.0s) probing: 3000/3840 (78.1%) - 1 fixings, 613 aggregations, 2864632 implications, 23 bound changes
#    (14.8s) probing cycle finished: starting next cycle
#    (15.0s) probing: 126/3226 (3.9%) - 1 fixings, 613 aggregations, 3206742 implications, 23 bound changes
#    (15.0s) probing aborted: 1000/1000 successive useless probings
# (round 108, exhaustive) 11702 del vars, 37808 del conss, 12795 add conss, 8275 chg bounds, 30034 chg sides, 31248 chg coeffs, 9067 upgd conss, 530341 impls, 77335 clqs
# (round 109, fast)       11702 del vars, 37813 del conss, 12795 add conss, 8275 chg bounds, 30112 chg sides, 31397 chg coeffs, 9067 upgd conss, 530341 impls, 77335 clqs
# (round 110, medium)     11703 del vars, 37837 del conss, 12795 add conss, 8275 chg bounds, 30113 chg sides, 31398 chg coeffs, 9067 upgd conss, 530341 impls, 77292 clqs
# (round 111, exhaustive) 11703 del vars, 37840 del conss, 12798 add conss, 8275 chg bounds, 30113 chg sides, 31398 chg coeffs, 9067 upgd conss, 530341 impls, 77292 clqs
#    (15.2s) probing: 226/3226 (7.0%) - 1 fixings, 613 aggregations, 3280071 implications, 23 bound changes
#    (15.2s) probing aborted: 1000/1000 successive useless probings
#    (15.2s) symmetry computation started: requiring (bin +, int -, cont +), (fixed: bin -, int +, cont -)
#    (15.2s) no symmetry present
#    (15.2s) symmetry computation started: requiring (bin +, int +, cont +), (fixed: bin -, int -, cont -)
#    (15.2s) symmetry computation finished: 7 generators found (max: 1500, log10 of symmetry group size: 3.5)
#    (15.2s) no symmetry on binary variables present.
#    (15.2s) -> no handable symmetry found, free symmetry data.
# presolving (112 rounds: 112 fast, 75 medium, 46 exhaustive):
#  11703 deleted vars, 37841 deleted constraints, 12798 added constraints, 8275 tightened bounds, 0 added holes, 30113 changed sides, 31398 changed coefficients
#  530349 implications, 77856 cliques
# presolved problem has 3916 variables (3225 bin, 691 int, 0 impl, 0 cont) and 5988 constraints
#    3580 constraints of type <varbound>
#    1700 constraints of type <setppc>
#      67 constraints of type <and>
#     641 constraints of type <linear>
# transformed objective value is always integral (scale: 0.001)
# Presolving Time: 15.18
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  15.4s|     1 |     0 |  2670 |     - |   152M |   0 |3916 |6011 |6055 |   0 |  0 |  22 |   0 | 1.098439e+06 |      --      |    Inf | unknown
#  15.8s|     1 |     0 |  3683 |     - |   159M |   0 |3916 |6011 |6145 |  90 |  1 |  22 |   0 | 1.098413e+06 |      --      |    Inf | unknown
#  16.0s|     1 |     0 |  3767 |     - |   161M |   0 |3916 |6011 |6192 | 137 |  2 |  22 |   0 | 1.098101e+06 |      --      |    Inf | unknown
#  16.2s|     1 |     0 |  3862 |     - |   163M |   0 |3916 |6011 |6290 | 235 |  3 |  22 |   0 | 1.097610e+06 |      --      |    Inf | unknown
#  16.4s|     1 |     0 |  3898 |     - |   164M |   0 |3916 |6011 |6308 | 253 |  4 |  22 |   0 | 1.097520e+06 |      --      |    Inf | unknown
#  16.6s|     1 |     0 |  4030 |     - |   165M |   0 |3916 |6012 |6386 | 331 |  5 |  23 |   0 | 1.097275e+06 |      --      |    Inf | unknown
#  16.8s|     1 |     0 |  4056 |     - |   166M |   0 |3916 |6012 |6398 | 343 |  6 |  23 |   0 | 1.097183e+06 |      --      |    Inf | unknown
#  17.0s|     1 |     0 |  4115 |     - |   166M |   0 |3916 |6012 |6456 | 401 |  7 |  23 |   0 | 1.097104e+06 |      --      |    Inf | unknown
#  17.2s|     1 |     0 |  4138 |     - |   167M |   0 |3916 |6012 |6472 | 417 |  8 |  23 |   0 | 1.096987e+06 |      --      |    Inf | unknown
#  17.4s|     1 |     0 |  4178 |     - |   168M |   0 |3916 |6012 |6494 | 439 |  9 |  23 |   0 | 1.096905e+06 |      --      |    Inf | unknown
#  17.6s|     1 |     0 |  4195 |     - |   169M |   0 |3916 |6012 |6505 | 450 | 10 |  23 |   0 | 1.096880e+06 |      --      |    Inf | unknown
#  17.6s|     1 |     0 |  4218 |     - |   170M |   0 |3916 |6012 |6526 | 471 | 11 |  23 |   0 | 1.096860e+06 |      --      |    Inf | unknown
#  17.7s|     1 |     0 |  4225 |     - |   170M |   0 |3916 |6013 |6533 | 478 | 12 |  24 |   0 | 1.096860e+06 |      --      |    Inf | unknown
#  17.7s|     1 |     0 |  4229 |     - |   171M |   0 |3916 |6013 |6536 | 481 | 13 |  24 |   0 | 1.096860e+06 |      --      |    Inf | unknown
#  17.7s|     1 |     0 |  4248 |     - |   172M |   0 |3916 |6013 |6555 | 500 | 14 |  24 |   0 | 1.096828e+06 |      --      |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  17.8s|     1 |     0 |  4259 |     - |   173M |   0 |3916 |6013 |6562 | 507 | 15 |  24 |   0 | 1.096828e+06 |      --      |    Inf | unknown
#  17.9s|     1 |     0 |  4263 |     - |   173M |   0 |3916 |6015 |6412 | 511 | 16 |  26 |   0 | 1.096828e+06 |      --      |    Inf | unknown
#  17.9s|     1 |     0 |  4278 |     - |   174M |   0 |3916 |6015 |6427 | 526 | 17 |  26 |   0 | 1.096824e+06 |      --      |    Inf | unknown
#  18.0s|     1 |     0 |  4283 |     - |   175M |   0 |3916 |6015 |6433 | 532 | 18 |  26 |   0 | 1.096824e+06 |      --      |    Inf | unknown
# d18.2s|     1 |     0 |  5309 |     - |farkasdi|   0 |3916 |6015 |6433 |   0 | 18 |  26 |   0 | 1.096824e+06 | 1.052136e+06 |   4.25%| unknown
# d18.2s|     1 |     0 |  6375 |     - |conflict|   0 |3916 |6015 |6433 |   0 | 18 |  26 |   0 | 1.096824e+06 | 1.082294e+06 |   1.34%| unknown
#  18.3s|     1 |     0 |  6376 |     - |   175M |   0 |3916 |6015 |6433 | 532 | 18 |  26 |   0 | 1.096824e+06 | 1.082294e+06 |   1.34%| unknown
#  18.3s|     1 |     0 |  6376 |     - |   176M |   0 |3916 |6018 |5789 | 532 | 18 |  29 |   0 | 1.096824e+06 | 1.082294e+06 |   1.34%| unknown
#  18.4s|     1 |     0 |  6388 |     - |   177M |   0 |3916 |5889 |4917 | 546 | 19 |  29 |   0 | 1.096813e+06 | 1.082294e+06 |   1.34%| unknown
#  18.5s|     1 |     0 |  6388 |     - |   177M |   0 |3916 |5889 |4917 | 546 | 19 |  29 |   0 | 1.096813e+06 | 1.082294e+06 |   1.34%| unknown
#  18.5s|     1 |     0 |  6393 |     - |   177M |   0 |3916 |5889 |4743 | 548 | 20 |  29 |   0 | 1.096810e+06 | 1.082294e+06 |   1.34%| unknown
#  18.5s|     1 |     0 |  6393 |     - |   177M |   0 |3916 |5892 |4743 | 548 | 20 |  32 |   0 | 1.096810e+06 | 1.082294e+06 |   1.34%| unknown
#  18.5s|     1 |     0 |  6394 |     - |   177M |   0 |3916 |4053 |4743 | 548 | 20 |  32 |   0 | 1.096810e+06 | 1.082294e+06 |   1.34%| unknown
#  18.5s|     1 |     0 |  6397 |     - |   178M |   0 |3916 |4053 |4745 | 550 | 21 |  32 |   0 | 1.096808e+06 | 1.082294e+06 |   1.34%| unknown
#  18.5s|     1 |     0 |  6397 |     - |   178M |   0 |3916 |4054 |4574 | 550 | 21 |  33 |   0 | 1.096808e+06 | 1.082294e+06 |   1.34%| unknown
# (run 1, node 1) restarting after 1138 global fixings of integer variables
#
# (restart) converted 147 cuts from the global cut pool into linear constraints
#
# presolving:
# (round 1, fast)       1226 del vars, 131 del conss, 0 add conss, 1 chg bounds, 408 chg sides, 767 chg coeffs, 0 upgd conss, 531040 impls, 30854 clqs
# (round 2, fast)       1234 del vars, 157 del conss, 0 add conss, 3 chg bounds, 418 chg sides, 792 chg coeffs, 0 upgd conss, 531052 impls, 30823 clqs
# (round 3, medium)     1239 del vars, 157 del conss, 0 add conss, 26 chg bounds, 423 chg sides, 797 chg coeffs, 0 upgd conss, 531052 impls, 30788 clqs
# (round 4, fast)       1239 del vars, 157 del conss, 0 add conss, 26 chg bounds, 457 chg sides, 848 chg coeffs, 0 upgd conss, 531052 impls, 30788 clqs
# (round 5, exhaustive) 1239 del vars, 159 del conss, 2 add conss, 26 chg bounds, 457 chg sides, 848 chg coeffs, 0 upgd conss, 531052 impls, 30788 clqs
# (round 6, exhaustive) 1239 del vars, 163 del conss, 2 add conss, 26 chg bounds, 457 chg sides, 848 chg coeffs, 0 upgd conss, 531052 impls, 30788 clqs
# (round 7, exhaustive) 1239 del vars, 175 del conss, 2 add conss, 26 chg bounds, 457 chg sides, 848 chg coeffs, 0 upgd conss, 531052 impls, 30788 clqs
# (round 8, exhaustive) 1239 del vars, 175 del conss, 2 add conss, 26 chg bounds, 457 chg sides, 848 chg coeffs, 126 upgd conss, 531052 impls, 30788 clqs
# (round 9, fast)       1239 del vars, 175 del conss, 2 add conss, 26 chg bounds, 465 chg sides, 857 chg coeffs, 126 upgd conss, 531053 impls, 30788 clqs
# (round 10, medium)     1239 del vars, 179 del conss, 2 add conss, 26 chg bounds, 465 chg sides, 857 chg coeffs, 126 upgd conss, 531053 impls, 30788 clqs
# presolving (11 rounds: 11 fast, 7 medium, 5 exhaustive):
#  1239 deleted vars, 179 deleted constraints, 2 added constraints, 26 tightened bounds, 0 added holes, 465 changed sides, 857 changed coefficients
#  531053 implications, 30788 cliques
# presolved problem has 2677 variables (1987 bin, 690 int, 0 impl, 0 cont) and 4024 constraints
#    2319 constraints of type <varbound>
#    1098 constraints of type <setppc>
#      35 constraints of type <and>
#     542 constraints of type <linear>
#      30 constraints of type <bounddisjunction>
# transformed objective value is always integral (scale: 0.001)
# Presolving Time: 15.22
# transformed 1/2 original solutions to the transformed problem space
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  18.7s|     1 |     0 |  8699 |     - |   174M |   0 |2677 |4024 |4029 |   0 |  0 |  33 |   0 | 1.096799e+06 | 1.082294e+06 |   1.34%| unknown
#  18.7s|     1 |     0 |  8699 |     - |   174M |   0 |2677 |4024 |4029 |   0 |  0 |  33 |   0 | 1.096799e+06 | 1.082294e+06 |   1.34%| unknown
#  18.9s|     1 |     0 |  8864 |     - |   175M |   0 |2677 |4024 |4283 | 273 |  1 |  33 |   0 | 1.096799e+06 | 1.082294e+06 |   1.34%| unknown
#  19.0s|     1 |     0 |  8897 |     - |   175M |   0 |2677 |4021 |4317 | 313 |  2 |  33 |   0 | 1.096799e+06 | 1.082294e+06 |   1.34%| unknown
#  19.1s|     1 |     0 |  8903 |     - |   176M |   0 |2677 |4021 |4321 | 317 |  3 |  33 |   0 | 1.096799e+06 | 1.082294e+06 |   1.34%| unknown
#  19.2s|     1 |     0 |  8911 |     - |   176M |   0 |2677 |4021 |4327 | 323 |  4 |  33 |   0 | 1.096799e+06 | 1.082294e+06 |   1.34%| unknown
#  19.3s|     1 |     0 |  8916 |     - |   177M |   0 |2677 |4021 |4330 | 326 |  5 |  33 |   0 | 1.096799e+06 | 1.082294e+06 |   1.34%| unknown
#  19.4s|     1 |     0 |  9176 |     - |   177M |   0 |2677 |4023 |4333 | 329 |  6 |  35 |   0 | 1.096799e+06 | 1.082294e+06 |   1.34%| unknown
# d19.8s|     1 |     0 |  9675 |     - |farkasdi|   0 |2677 |4009 |4333 |   0 |  8 |  43 |   0 | 1.096799e+06 | 1.090599e+06 |   0.57%| unknown
#  19.8s|     1 |     0 |  9761 |     - |   179M |   0 |2677 |4015 |4333 | 329 |  8 |  49 |   0 | 1.096799e+06 | 1.090599e+06 |   0.57%| unknown
#  19.9s|     1 |     0 |  9761 |     - |   179M |   0 |2677 |4015 |4267 | 329 |  8 |  49 |   0 | 1.096799e+06 | 1.090599e+06 |   0.57%| unknown
#  20.0s|     1 |     0 |  9765 |     - |   179M |   0 |2677 |4014 |4217 | 332 |  9 |  49 |   0 | 1.096791e+06 | 1.090599e+06 |   0.57%| unknown
#  20.0s|     1 |     0 |  9765 |     - |   179M |   0 |2677 |4014 |4217 | 332 |  9 |  49 |   0 | 1.096791e+06 | 1.090599e+06 |   0.57%| unknown
#  20.0s|     1 |     0 |  9790 |     - |   179M |   0 |2677 |3500 |4217 | 332 | 10 |  49 |   0 | 1.096675e+06 | 1.090599e+06 |   0.56%| unknown
#  20.0s|     1 |     0 |  9801 |     - |   179M |   0 |2677 |3501 |3832 | 332 | 10 |  50 |   0 | 1.096675e+06 | 1.090599e+06 |   0.56%| unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  20.1s|     1 |     0 |  9814 |     - |   180M |   0 |2677 |3501 |3839 | 341 | 11 |  50 |   0 | 1.096661e+06 | 1.090599e+06 |   0.56%| unknown
#  20.1s|     1 |     0 |  9814 |     - |   180M |   0 |2677 |3501 |3838 | 341 | 11 |  50 |   0 | 1.096661e+06 | 1.090599e+06 |   0.56%| unknown
#  20.1s|     1 |     0 |  9814 |     - |   180M |   0 |2677 |3494 |3838 | 341 | 12 |  50 |   0 | 1.096661e+06 | 1.090599e+06 |   0.56%| unknown
#  20.2s|     1 |     0 |  9834 |     - |   180M |   0 |2677 |3494 |3793 | 347 | 13 |  50 |   0 | 1.096606e+06 | 1.090599e+06 |   0.55%| unknown
#  20.2s|     1 |     0 |  9838 |     - |   180M |   0 |2677 |3495 |3791 | 347 | 13 |  51 |   0 | 1.096606e+06 | 1.090599e+06 |   0.55%| unknown
#  20.2s|     1 |     0 |  9840 |     - |   180M |   0 |2677 |3495 |3793 | 349 | 14 |  51 |   0 | 1.096606e+06 | 1.090599e+06 |   0.55%| unknown
#  20.2s|     1 |     0 |  9840 |     - |   180M |   0 |2677 |3494 |3793 | 349 | 14 |  52 |   0 | 1.096606e+06 | 1.090599e+06 |   0.55%| unknown
#  20.3s|     1 |     0 |  9843 |     - |   180M |   0 |2677 |3494 |3796 | 352 | 15 |  52 |   0 | 1.096604e+06 | 1.090599e+06 |   0.55%| unknown
#  20.3s|     1 |     0 |  9844 |     - |   181M |   0 |2677 |3494 |3795 | 352 | 15 |  52 |   0 | 1.096604e+06 | 1.090599e+06 |   0.55%| unknown
# (run 2, node 1) restarting after 285 global fixings of integer variables
#
# (restart) converted 323 cuts from the global cut pool into linear constraints
#
# presolving:
# (round 1, fast)       346 del vars, 65 del conss, 0 add conss, 0 chg bounds, 227 chg sides, 408 chg coeffs, 0 upgd conss, 531418 impls, 26559 clqs
# (round 2, fast)       346 del vars, 74 del conss, 0 add conss, 0 chg bounds, 227 chg sides, 408 chg coeffs, 0 upgd conss, 531418 impls, 26559 clqs
# (round 3, medium)     349 del vars, 74 del conss, 0 add conss, 12 chg bounds, 230 chg sides, 411 chg coeffs, 0 upgd conss, 531418 impls, 26543 clqs
# (round 4, fast)       349 del vars, 75 del conss, 1 add conss, 13 chg bounds, 252 chg sides, 436 chg coeffs, 0 upgd conss, 531418 impls, 26543 clqs
# (round 5, fast)       349 del vars, 75 del conss, 1 add conss, 14 chg bounds, 255 chg sides, 440 chg coeffs, 0 upgd conss, 531418 impls, 26543 clqs
# (round 6, medium)     350 del vars, 78 del conss, 1 add conss, 19 chg bounds, 262 chg sides, 448 chg coeffs, 0 upgd conss, 531422 impls, 26488 clqs
# (round 7, fast)       351 del vars, 78 del conss, 1 add conss, 19 chg bounds, 268 chg sides, 458 chg coeffs, 0 upgd conss, 531422 impls, 26488 clqs
# (round 8, exhaustive) 351 del vars, 79 del conss, 1 add conss, 19 chg bounds, 268 chg sides, 458 chg coeffs, 261 upgd conss, 531422 impls, 26488 clqs
# (round 9, fast)       351 del vars, 79 del conss, 1 add conss, 20 chg bounds, 273 chg sides, 465 chg coeffs, 261 upgd conss, 531426 impls, 26488 clqs
# (round 10, medium)     351 del vars, 88 del conss, 1 add conss, 20 chg bounds, 273 chg sides, 465 chg coeffs, 261 upgd conss, 531426 impls, 26488 clqs
# presolving (11 rounds: 11 fast, 5 medium, 2 exhaustive):
#  351 deleted vars, 88 deleted constraints, 1 added constraints, 20 tightened bounds, 0 added holes, 273 changed sides, 466 changed coefficients
#  531426 implications, 26488 cliques
# presolved problem has 2326 variables (1639 bin, 687 int, 0 impl, 0 cont) and 3729 constraints
#    2127 constraints of type <varbound>
#     952 constraints of type <setppc>
#      24 constraints of type <and>
#     579 constraints of type <linear>
#       1 constraints of type <logicor>
#      46 constraints of type <bounddisjunction>
# transformed objective value is always integral (scale: 0.001)
# Presolving Time: 15.25
# transformed 2/4 original solutions to the transformed problem space
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  20.4s|     1 |     0 | 12065 |     - |   182M |   0 |2326 |3729 |3706 |   0 |  0 |  52 |   0 | 1.096593e+06 | 1.090599e+06 |   0.55%| unknown
#  20.4s|     1 |     0 | 12320 |     - |   182M |   0 |2326 |3730 |3706 |   0 |  0 |  53 |   0 | 1.096593e+06 | 1.090599e+06 |   0.55%| unknown
#  20.7s|     1 |     0 | 12366 |     - |   183M |   0 |2326 |3734 |3670 |  23 |  1 |  53 |   0 | 1.096536e+06 | 1.090599e+06 |   0.54%| unknown
#  20.7s|     1 |     0 | 12378 |     - |   183M |   0 |2326 |3734 |3670 |  23 |  1 |  53 |   0 | 1.096536e+06 | 1.090599e+06 |   0.54%| unknown
#  20.8s|     1 |     0 | 12420 |     - |   183M |   0 |2326 |3731 |3679 |  32 |  2 |  55 |   0 | 1.096483e+06 | 1.090599e+06 |   0.54%| unknown
#  20.8s|     1 |     0 | 12430 |     - |   183M |   0 |2326 |3731 |3679 |  32 |  2 |  55 |   0 | 1.096483e+06 | 1.090599e+06 |   0.54%| unknown
#  20.9s|     1 |     0 | 12457 |     - |   184M |   0 |2326 |3731 |3689 |  42 |  3 |  55 |   0 | 1.096455e+06 | 1.090599e+06 |   0.54%| unknown
#  20.9s|     1 |     0 | 12458 |     - |   184M |   0 |2326 |3731 |3689 |  42 |  3 |  55 |   0 | 1.096455e+06 | 1.090599e+06 |   0.54%| unknown
#  21.0s|     1 |     0 | 12535 |     - |   184M |   0 |2326 |3732 |3697 |  50 |  4 |  56 |   0 | 1.096415e+06 | 1.090599e+06 |   0.53%| unknown
#  21.0s|     1 |     0 | 12546 |     - |   184M |   0 |2326 |3732 |3696 |  50 |  4 |  56 |   0 | 1.096415e+06 | 1.090599e+06 |   0.53%| unknown
#  21.1s|     1 |     0 | 12573 |     - |   185M |   0 |2326 |3732 |3698 |  53 |  5 |  56 |   0 | 1.096367e+06 | 1.090599e+06 |   0.53%| unknown
#  21.1s|     1 |     0 | 12573 |     - |   185M |   0 |2326 |3732 |3698 |  53 |  5 |  56 |   0 | 1.096367e+06 | 1.090599e+06 |   0.53%| unknown
#  21.2s|     1 |     0 | 12605 |     - |   185M |   0 |2326 |3732 |3703 |  58 |  6 |  56 |   0 | 1.096307e+06 | 1.090599e+06 |   0.52%| unknown
#  21.2s|     1 |     0 | 12606 |     - |   185M |   0 |2326 |3732 |3701 |  58 |  6 |  56 |   0 | 1.096307e+06 | 1.090599e+06 |   0.52%| unknown
#  21.3s|     1 |     0 | 12615 |     - |   185M |   0 |2326 |3732 |3708 |  67 |  7 |  56 |   0 | 1.096283e+06 | 1.090599e+06 |   0.52%| unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  21.3s|     1 |     0 | 12615 |     - |   185M |   0 |2326 |3732 |3707 |  67 |  7 |  56 |   0 | 1.096283e+06 | 1.090599e+06 |   0.52%| unknown
#  21.4s|     1 |     0 | 12640 |     - |   186M |   0 |2326 |3732 |3718 |  78 |  8 |  56 |   0 | 1.096253e+06 | 1.090599e+06 |   0.52%| unknown
#  21.4s|     1 |     0 | 12640 |     - |   186M |   0 |2326 |3732 |3718 |  78 |  8 |  56 |   0 | 1.096253e+06 | 1.090599e+06 |   0.52%| unknown
#  21.5s|     1 |     0 | 12662 |     - |   186M |   0 |2326 |3732 |3724 |  84 |  9 |  56 |   0 | 1.096239e+06 | 1.090599e+06 |   0.52%| unknown
#  21.5s|     1 |     0 | 12662 |     - |   186M |   0 |2326 |3732 |3720 |  84 |  9 |  56 |   0 | 1.096239e+06 | 1.090599e+06 |   0.52%| unknown
#  21.5s|     1 |     0 | 12671 |     - |   187M |   0 |2326 |3732 |3723 |  89 | 10 |  56 |   0 | 1.096239e+06 | 1.090599e+06 |   0.52%| unknown
#  21.5s|     1 |     0 | 12671 |     - |   187M |   0 |2326 |3732 |3723 |  89 | 10 |  56 |   0 | 1.096239e+06 | 1.090599e+06 |   0.52%| unknown
#  21.6s|     1 |     0 | 12674 |     - |   187M |   0 |2326 |3732 |3724 |  90 | 11 |  56 |   0 | 1.096238e+06 | 1.090599e+06 |   0.52%| unknown
#  21.6s|     1 |     0 | 12674 |     - |   187M |   0 |2326 |3732 |3724 |  90 | 11 |  56 |   0 | 1.096238e+06 | 1.090599e+06 |   0.52%| unknown
#  21.6s|     1 |     0 | 12674 |     - |   187M |   0 |2326 |3664 |3724 |  90 | 11 |  56 |   0 | 1.096238e+06 | 1.090599e+06 |   0.52%| unknown
# d21.7s|     1 |     0 | 13129 |     - |farkasdi|   0 |2326 |3666 |3724 |   0 | 13 |  58 |   0 | 1.096238e+06 | 1.090605e+06 |   0.52%| unknown
# d21.8s|     1 |     0 | 13593 |     - |conflict|   0 |2326 |3678 |3724 |   0 | 13 |  72 |   0 | 1.096238e+06 | 1.093493e+06 |   0.25%| unknown
#  21.8s|     1 |     0 | 13593 |     - |   188M |   0 |2326 |3676 |3724 |  90 | 13 |  72 |   0 | 1.096238e+06 | 1.093493e+06 |   0.25%| unknown
#  21.9s|     1 |     0 | 13593 |     - |   188M |   0 |2326 |3676 |3616 |  90 | 13 |  72 |   0 | 1.096238e+06 | 1.093493e+06 |   0.25%| unknown
#  21.9s|     1 |     0 | 13603 |     - |   188M |   0 |2326 |3667 |3506 |  99 | 14 |  72 |   0 | 1.096238e+06 | 1.093493e+06 |   0.25%| unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  21.9s|     1 |     0 | 13603 |     - |   188M |   0 |2326 |3668 |3506 |  99 | 14 |  73 |   0 | 1.096238e+06 | 1.093493e+06 |   0.25%| unknown
#  21.9s|     1 |     0 | 13604 |     - |   188M |   0 |2326 |3668 |3507 | 100 | 15 |  73 |   0 | 1.096238e+06 | 1.093493e+06 |   0.25%| unknown
#  22.0s|     1 |     0 | 13636 |     - |   188M |   0 |2326 |3234 |3507 | 100 | 15 |  75 |   0 | 1.096181e+06 | 1.093493e+06 |   0.25%| unknown
#  22.0s|     1 |     0 | 13638 |     - |   188M |   0 |2326 |3234 |3330 | 100 | 15 |  75 |   0 | 1.096181e+06 | 1.093493e+06 |   0.25%| unknown
#  22.0s|     1 |     0 | 13708 |     - |   188M |   0 |2326 |3234 |2969 | 116 | 16 |  75 |   0 | 1.096157e+06 | 1.093493e+06 |   0.24%| unknown
#  22.0s|     1 |     0 | 13718 |     - |   188M |   0 |2326 |3234 |2969 | 116 | 16 |  75 |   0 | 1.096157e+06 | 1.093493e+06 |   0.24%| unknown
#  22.0s|     1 |     0 | 13719 |     - |   188M |   0 |2326 |3234 |2970 | 117 | 17 |  75 |   0 | 1.096157e+06 | 1.093493e+06 |   0.24%| unknown
#  22.0s|     1 |     0 | 13719 |     - |   188M |   0 |2326 |3234 |2970 | 117 | 17 |  75 |   0 | 1.096157e+06 | 1.093493e+06 |   0.24%| unknown
#  22.0s|     1 |     0 | 13719 |     - |   188M |   0 |2326 |3171 |2970 | 117 | 17 |  75 |   0 | 1.096157e+06 | 1.093493e+06 |   0.24%| unknown
#  22.1s|     1 |     0 | 13721 |     - |   189M |   0 |2326 |3171 |2972 | 119 | 18 |  75 |   0 | 1.096157e+06 | 1.093493e+06 |   0.24%| unknown
# (run 3, node 1) restarting after 311 global fixings of integer variables
#
# (restart) converted 83 cuts from the global cut pool into linear constraints
#
# presolving:
# (round 1, fast)       411 del vars, 118 del conss, 0 add conss, 8 chg bounds, 464 chg sides, 832 chg coeffs, 0 upgd conss, 532147 impls, 12781 clqs
# (round 2, fast)       415 del vars, 162 del conss, 0 add conss, 14 chg bounds, 472 chg sides, 849 chg coeffs, 0 upgd conss, 532163 impls, 12726 clqs
# (round 3, fast)       415 del vars, 163 del conss, 0 add conss, 15 chg bounds, 478 chg sides, 862 chg coeffs, 0 upgd conss, 532163 impls, 12726 clqs
# (round 4, fast)       417 del vars, 166 del conss, 0 add conss, 18 chg bounds, 483 chg sides, 866 chg coeffs, 0 upgd conss, 532167 impls, 12715 clqs
# (round 5, fast)       417 del vars, 166 del conss, 0 add conss, 18 chg bounds, 489 chg sides, 873 chg coeffs, 0 upgd conss, 532167 impls, 12715 clqs
# (round 6, medium)     421 del vars, 166 del conss, 0 add conss, 48 chg bounds, 493 chg sides, 877 chg coeffs, 0 upgd conss, 532167 impls, 12690 clqs
# (round 7, fast)       421 del vars, 167 del conss, 1 add conss, 48 chg bounds, 521 chg sides, 915 chg coeffs, 0 upgd conss, 532167 impls, 12690 clqs
# (round 8, exhaustive) 421 del vars, 170 del conss, 3 add conss, 48 chg bounds, 521 chg sides, 915 chg coeffs, 0 upgd conss, 532167 impls, 12690 clqs
# (round 9, exhaustive) 421 del vars, 176 del conss, 3 add conss, 48 chg bounds, 521 chg sides, 915 chg coeffs, 0 upgd conss, 532167 impls, 12690 clqs
# (round 10, exhaustive) 421 del vars, 176 del conss, 3 add conss, 48 chg bounds, 521 chg sides, 915 chg coeffs, 37 upgd conss, 532167 impls, 12690 clqs
# (round 11, fast)       421 del vars, 177 del conss, 3 add conss, 48 chg bounds, 525 chg sides, 920 chg coeffs, 37 upgd conss, 532167 impls, 12690 clqs
# (round 12, medium)     421 del vars, 187 del conss, 3 add conss, 48 chg bounds, 525 chg sides, 920 chg coeffs, 37 upgd conss, 532167 impls, 12690 clqs
# presolving (13 rounds: 13 fast, 6 medium, 4 exhaustive):
#  421 deleted vars, 187 deleted constraints, 3 added constraints, 48 tightened bounds, 0 added holes, 525 changed sides, 921 changed coefficients
#  532167 implications, 12690 cliques
# presolved problem has 1905 variables (1222 bin, 683 int, 0 impl, 0 cont) and 3072 constraints
#    1698 constraints of type <varbound>
#     694 constraints of type <setppc>
#      17 constraints of type <and>
#     597 constraints of type <linear>
#       2 constraints of type <logicor>
#      64 constraints of type <bounddisjunction>
# transformed objective value is always integral (scale: 0.001)
# Presolving Time: 15.29
# transformed 3/8 original solutions to the transformed problem space
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  22.2s|     1 |     0 | 15760 |     - |   191M |   0 |1905 |3072 |3021 |   0 |  0 |  77 |   0 | 1.096119e+06 | 1.093493e+06 |   0.24%| unknown
#  22.2s|     1 |     0 | 15933 |     - |   191M |   0 |1905 |3072 |3020 |   0 |  0 |  77 |   0 | 1.096119e+06 | 1.093493e+06 |   0.24%| unknown
#  22.2s|     1 |     0 | 15933 |     - |   191M |   0 |1905 |3072 |3018 |   0 |  0 |  77 |   0 | 1.096119e+06 | 1.093493e+06 |   0.24%| unknown
#  22.4s|     1 |     0 | 15966 |     - |   191M |   0 |1905 |3072 |3015 |  43 |  1 |  77 |   0 | 1.096096e+06 | 1.093493e+06 |   0.24%| unknown
#  22.4s|     1 |     0 | 15982 |     - |   192M |   0 |1905 |3072 |3015 |  43 |  1 |  77 |   0 | 1.096096e+06 | 1.093493e+06 |   0.24%| unknown
#  22.4s|     1 |     0 | 16002 |     - |   192M |   0 |1905 |3070 |3015 |  50 |  2 |  77 |   0 | 1.096086e+06 | 1.093493e+06 |   0.24%| unknown
#  22.5s|     1 |     0 | 16002 |     - |   192M |   0 |1905 |3070 |3015 |  50 |  2 |  77 |   0 | 1.096086e+06 | 1.093493e+06 |   0.24%| unknown
#  22.5s|     1 |     0 | 16014 |     - |   192M |   0 |1905 |3070 |3019 |  54 |  3 |  77 |   0 | 1.096083e+06 | 1.093493e+06 |   0.24%| unknown
#  22.5s|     1 |     0 | 16014 |     - |   192M |   0 |1905 |3071 |3019 |  54 |  3 |  78 |   0 | 1.096083e+06 | 1.093493e+06 |   0.24%| unknown
#  22.6s|     1 |     0 | 16023 |     - |   192M |   0 |1905 |3071 |3021 |  56 |  4 |  78 |   0 | 1.096073e+06 | 1.093493e+06 |   0.24%| unknown
#  22.6s|     1 |     0 | 16023 |     - |   192M |   0 |1905 |3071 |3021 |  56 |  4 |  78 |   0 | 1.096073e+06 | 1.093493e+06 |   0.24%| unknown
#  22.7s|     1 |     0 | 16025 |     - |   192M |   0 |1905 |3071 |3023 |  58 |  6 |  78 |   0 | 1.096073e+06 | 1.093493e+06 |   0.24%| unknown
#  22.8s|     1 |     0 | 16025 |     - |   193M |   0 |1905 |3015 |3023 |  58 |  8 |  79 |   0 | 1.096073e+06 | 1.093493e+06 |   0.24%| unknown
# d23.0s|     1 |     0 | 16632 |     - |conflict|   0 |1905 |3015 |3023 |   0 | 10 |  80 |   0 | 1.096073e+06 | 1.094801e+06 |   0.12%| unknown
#  23.0s|     1 |     0 | 16668 |     - |   193M |   0 |1905 |2964 |3023 |  58 | 10 |  80 |   0 | 1.095995e+06 | 1.094801e+06 |   0.11%| unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  23.0s|     1 |     0 | 16668 |     - |   193M |   0 |1905 |2964 |2909 |  58 | 10 |  80 |   0 | 1.095995e+06 | 1.094801e+06 |   0.11%| unknown
#  23.1s|     1 |     0 | 16688 |     - |   193M |   0 |1905 |2962 |2813 |  64 | 11 |  80 |   0 | 1.095979e+06 | 1.094801e+06 |   0.11%| unknown
#  23.2s|     1 |     0 | 16688 |     - |   193M |   0 |1905 |2961 |2813 |  64 | 11 |  80 |   0 | 1.095979e+06 | 1.094801e+06 |   0.11%| unknown
#  23.2s|     1 |     0 | 16690 |     - |   193M |   0 |1905 |2961 |2816 |  67 | 12 |  80 |   0 | 1.095979e+06 | 1.094801e+06 |   0.11%| unknown
#  23.2s|     1 |     0 | 16690 |     - |   193M |   0 |1905 |2961 |2816 |  67 | 12 |  80 |   0 | 1.095979e+06 | 1.094801e+06 |   0.11%| unknown
#  23.2s|     1 |     0 | 16691 |     - |   193M |   0 |1905 |2679 |2816 |  67 | 12 |  80 |   0 | 1.095979e+06 | 1.094801e+06 |   0.11%| unknown
#  23.2s|     1 |     0 | 16691 |     - |   193M |   0 |1905 |2679 |2726 |  67 | 12 |  80 |   0 | 1.095979e+06 | 1.094801e+06 |   0.11%| unknown
#  23.3s|     1 |     0 | 16712 |     - |   194M |   0 |1905 |2679 |2740 |  81 | 13 |  80 |   0 | 1.095857e+06 | 1.094801e+06 |   0.10%| unknown
#  23.3s|     1 |     0 | 16712 |     - |   194M |   0 |1905 |2679 |2740 |  81 | 13 |  80 |   0 | 1.095857e+06 | 1.094801e+06 |   0.10%| unknown
#  23.3s|     1 |     0 | 16748 |     - |   194M |   0 |1905 |2679 |2742 |  83 | 14 |  80 |   0 | 1.095837e+06 | 1.094801e+06 |   0.09%| unknown
#  23.3s|     1 |     0 | 16748 |     - |   194M |   0 |1905 |2679 |2742 |  83 | 14 |  80 |   0 | 1.095837e+06 | 1.094801e+06 |   0.09%| unknown
#  23.3s|     1 |     0 | 16748 |     - |   194M |   0 |1905 |2679 |2742 |  83 | 14 |  80 |   0 | 1.095837e+06 | 1.094801e+06 |   0.09%| unknown
#  23.4s|     1 |     0 | 16772 |     - |   194M |   0 |1905 |2679 |2756 |  97 | 15 |  80 |   0 | 1.095805e+06 | 1.094801e+06 |   0.09%| unknown
#  23.4s|     1 |     0 | 16779 |     - |   194M |   0 |1905 |2679 |2755 |  97 | 15 |  80 |   0 | 1.095805e+06 | 1.094801e+06 |   0.09%| unknown
#  23.4s|     1 |     0 | 16780 |     - |   194M |   0 |1905 |2680 |2756 |  98 | 16 |  81 |   0 | 1.095805e+06 | 1.094801e+06 |   0.09%| unknown
# ...
# (round 77, exhaustive) 614 del vars, 1036 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 78, fast)       615 del vars, 1037 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 79, exhaustive) 616 del vars, 1037 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 80, fast)       617 del vars, 1038 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 81, exhaustive) 618 del vars, 1038 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 82, fast)       619 del vars, 1039 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 83, exhaustive) 620 del vars, 1039 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 84, fast)       621 del vars, 1040 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 85, exhaustive) 622 del vars, 1040 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 86, fast)       623 del vars, 1041 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 87, exhaustive) 624 del vars, 1041 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 88, fast)       625 del vars, 1042 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 89, exhaustive) 626 del vars, 1042 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 90, fast)       627 del vars, 1043 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 91, exhaustive) 628 del vars, 1043 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 92, fast)       629 del vars, 1044 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 93, exhaustive) 630 del vars, 1044 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 94, fast)       631 del vars, 1045 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 95, exhaustive) 632 del vars, 1045 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 96, fast)       633 del vars, 1046 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 97, exhaustive) 634 del vars, 1046 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# (round 98, fast)       635 del vars, 1047 del conss, 0 add conss, 516 chg bounds, 243 chg sides, 414 chg coeffs, 25 upgd conss, 534265 impls, 1405 clqs
# presolving (99 rounds: 99 fast, 36 medium, 33 exhaustive):
#  635 deleted vars, 1047 deleted constraints, 0 added constraints, 516 tightened bounds, 0 added holes, 243 changed sides, 414 changed coefficients
#  534265 implications, 1405 cliques
# presolved problem has 848 variables (250 bin, 598 int, 0 impl, 0 cont) and 1043 constraints
#     494 constraints of type <varbound>
#     100 constraints of type <setppc>
#     434 constraints of type <linear>
#      15 constraints of type <bounddisjunction>
# transformed objective value is always integral (scale: 0.001)
# Presolving Time: 15.42
# transformed 1/14 original solutions to the transformed problem space
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  24.8s|     1 |     0 | 19656 |     - |   200M |   0 | 848 |1043 |1023 |   0 |  0 | 103 |  16 | 1.095321e+06 | 1.095172e+06 |   0.01%| unknown
#  24.8s|     1 |     0 | 19721 |     - |   200M |   0 | 848 |1043 |1023 |   0 |  0 | 103 |  16 | 1.095321e+06 | 1.095172e+06 |   0.01%| unknown
#  24.8s|     1 |     0 | 19751 |     - |   200M |   0 | 848 |1043 |1069 |  47 |  1 | 103 |  16 | 1.095272e+06 | 1.095172e+06 |   0.01%| unknown
#  24.8s|     1 |     0 | 19755 |     - |   200M |   0 | 848 |1043 |1069 |  47 |  1 | 103 |  16 | 1.095272e+06 | 1.095172e+06 |   0.01%| unknown
#  24.9s|     1 |     0 | 19775 |     - |   200M |   0 | 848 |1043 |1084 |  63 |  2 | 103 |  16 | 1.095269e+06 | 1.095172e+06 |   0.01%| unknown
#  24.9s|     1 |     0 | 19788 |     - |   200M |   0 | 848 |1043 |1084 |  63 |  2 | 103 |  16 | 1.095269e+06 | 1.095172e+06 |   0.01%| unknown
#  24.9s|     1 |     0 | 19797 |     - |   201M |   0 | 848 |1043 |1090 |  69 |  3 | 103 |  16 | 1.095267e+06 | 1.095172e+06 |   0.01%| unknown
#  24.9s|     1 |     0 | 19797 |     - |   201M |   0 | 848 |1043 |1090 |  69 |  3 | 103 |  16 | 1.095267e+06 | 1.095172e+06 |   0.01%| unknown
#  25.0s|     1 |     0 | 19805 |     - |   201M |   0 | 848 |1043 |1096 |  75 |  4 | 103 |  16 | 1.095267e+06 | 1.095172e+06 |   0.01%| unknown
#  25.0s|     1 |     0 | 19812 |     - |   201M |   0 | 848 |1043 |1096 |  75 |  4 | 103 |  16 | 1.095267e+06 | 1.095172e+06 |   0.01%| unknown
#  25.0s|     1 |     0 | 19823 |     - |   201M |   0 | 848 |1043 |1098 |  77 |  5 | 103 |  16 | 1.095265e+06 | 1.095172e+06 |   0.01%| unknown
#  25.0s|     1 |     0 | 19823 |     - |   201M |   0 | 848 |1045 |1098 |  77 |  5 | 105 |  16 | 1.095265e+06 | 1.095172e+06 |   0.01%| unknown
#  25.0s|     1 |     0 | 19831 |     - |   201M |   0 | 848 |1045 |1101 |  80 |  6 | 105 |  16 | 1.095265e+06 | 1.095172e+06 |   0.01%| unknown
#  25.0s|     1 |     0 | 19831 |     - |   201M |   0 | 848 |1046 |1101 |  80 |  6 | 106 |  16 | 1.095265e+06 | 1.095172e+06 |   0.01%| unknown
#  25.1s|     1 |     0 | 19833 |     - |   201M |   0 | 848 |1046 |1103 |  82 |  7 | 106 |  16 | 1.095264e+06 | 1.095172e+06 |   0.01%| unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  25.1s|     1 |     0 | 19833 |     - |   201M |   0 | 848 |1050 |1103 |  82 |  7 | 110 |  16 | 1.095264e+06 | 1.095172e+06 |   0.01%| unknown
#  25.1s|     1 |     0 | 19836 |     - |   202M |   0 | 848 |1050 |1105 |  84 |  8 | 110 |  16 | 1.095264e+06 | 1.095172e+06 |   0.01%| unknown
#  25.1s|     1 |     0 | 19836 |     - |   202M |   0 | 848 |1050 |1105 |  84 |  8 | 110 |  16 | 1.095264e+06 | 1.095172e+06 |   0.01%| unknown
#  25.2s|     1 |     0 | 19843 |     - |   202M |   0 | 848 |1050 |1108 |  87 |  9 | 110 |  16 | 1.095263e+06 | 1.095172e+06 |   0.01%| unknown
#  25.2s|     1 |     0 | 19843 |     - |   202M |   0 | 848 |1050 |1108 |  87 |  9 | 110 |  16 | 1.095263e+06 | 1.095172e+06 |   0.01%| unknown
#  25.2s|     1 |     0 | 19849 |     - |   202M |   0 | 848 |1050 |1112 |  91 | 10 | 110 |  16 | 1.095263e+06 | 1.095172e+06 |   0.01%| unknown
#  25.2s|     1 |     0 | 19849 |     - |   202M |   0 | 848 |1050 |1112 |  91 | 10 | 110 |  16 | 1.095263e+06 | 1.095172e+06 |   0.01%| unknown
#  25.2s|     1 |     0 | 19852 |     - |   202M |   0 | 848 |1050 |1114 |  93 | 11 | 110 |  16 | 1.095263e+06 | 1.095172e+06 |   0.01%| unknown
#  25.2s|     1 |     0 | 19852 |     - |   202M |   0 | 848 |1050 |1114 |  93 | 11 | 110 |  16 | 1.095263e+06 | 1.095172e+06 |   0.01%| unknown
#  25.2s|     1 |     0 | 19852 |     - |   202M |   0 | 848 |1007 |1114 |  93 | 11 | 110 |  16 | 1.095263e+06 | 1.095172e+06 |   0.01%| unknown
# d25.2s|     1 |     0 | 19963 |     - |farkasdi|   0 | 848 |1007 |1114 |   0 | 13 | 110 |  16 | 1.095263e+06 | 1.095254e+06 |   0.00%| unknown
#  25.3s|     1 |     0 | 20035 |     - |   202M |   0 | 848 |1006 |1114 |  93 | 13 | 112 |  16 | 1.095263e+06 | 1.095254e+06 |   0.00%| unknown
#  25.3s|     1 |     0 | 20035 |     - |   202M |   0 | 848 |1006 |1072 |  93 | 13 | 112 |  16 | 1.095263e+06 | 1.095254e+06 |   0.00%| unknown
#  25.3s|     1 |     0 | 20035 |     - |   202M |   0 | 848 |1006 |1071 |  93 | 14 | 112 |  16 | 1.095263e+06 | 1.095254e+06 |   0.00%| unknown
#  25.3s|     1 |     0 | 20035 |     - |   202M |   0 | 848 | 944 |1071 |  93 | 15 | 112 |  16 | 1.095263e+06 | 1.095254e+06 |   0.00%| unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  25.3s|     1 |     0 | 20039 |     - |   202M |   0 | 848 | 944 |1075 |  97 | 16 | 112 |  16 | 1.095263e+06 | 1.095254e+06 |   0.00%| unknown
#  25.3s|     1 |     0 | 20071 |     - |   202M |   0 | 848 | 711 |1075 |  97 | 17 | 115 |  17 | 1.095262e+06 | 1.095254e+06 |   0.00%| unknown
#  25.3s|     1 |     0 | 20084 |     - |   202M |   0 | 848 | 711 | 778 |  97 | 17 | 115 |  17 | 1.095262e+06 | 1.095254e+06 |   0.00%| unknown
#  25.3s|     1 |     0 | 20085 |     - |   202M |   0 | 848 | 711 | 773 |  98 | 18 | 115 |  17 | 1.095262e+06 | 1.095254e+06 |   0.00%| unknown
#  25.3s|     1 |     0 | 20085 |     - |   202M |   0 | 848 | 671 | 773 |  98 | 19 | 115 |  17 | 1.095262e+06 | 1.095254e+06 |   0.00%| unknown
# (run 6, node 1) restarting after 140 global fixings of integer variables
#
# (restart) converted 59 cuts from the global cut pool into linear constraints
#
# presolving:
# (round 1, fast)       191 del vars, 78 del conss, 0 add conss, 4 chg bounds, 30 chg sides, 123 chg coeffs, 0 upgd conss, 534354 impls, 45 clqs
# (round 2, exhaustive) 191 del vars, 83 del conss, 0 add conss, 9 chg bounds, 32 chg sides, 125 chg coeffs, 0 upgd conss, 534354 impls, 45 clqs
# (round 3, medium)     191 del vars, 83 del conss, 0 add conss, 11 chg bounds, 33 chg sides, 128 chg coeffs, 0 upgd conss, 534354 impls, 45 clqs
# (round 4, exhaustive) 191 del vars, 83 del conss, 0 add conss, 14 chg bounds, 33 chg sides, 128 chg coeffs, 44 upgd conss, 534354 impls, 45 clqs
# (round 5, fast)       191 del vars, 83 del conss, 0 add conss, 15 chg bounds, 56 chg sides, 151 chg coeffs, 44 upgd conss, 534354 impls, 45 clqs
# (round 6, medium)     191 del vars, 87 del conss, 0 add conss, 17 chg bounds, 56 chg sides, 151 chg coeffs, 44 upgd conss, 534354 impls, 45 clqs
# presolving (7 rounds: 7 fast, 5 medium, 3 exhaustive):
#  191 deleted vars, 87 deleted constraints, 0 added constraints, 20 tightened bounds, 0 added holes, 56 changed sides, 151 changed coefficients
#  534354 implications, 45 cliques
# presolved problem has 657 variables (85 bin, 572 int, 0 impl, 0 cont) and 643 constraints
#     251 constraints of type <varbound>
#      14 constraints of type <setppc>
#     370 constraints of type <linear>
#       8 constraints of type <bounddisjunction>
# transformed objective value is always integral (scale: 0.001)
# Presolving Time: 15.44
# transformed 2/16 original solutions to the transformed problem space
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  25.3s|     1 |     0 | 20638 |     - |   205M |   0 | 657 | 638 | 626 |   0 |  0 | 115 |  17 | 1.095262e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20638 |     - |   205M |   0 | 657 | 638 | 626 |   0 |  0 | 115 |  17 | 1.095262e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20668 |     - |   205M |   0 | 657 | 638 | 653 |  27 |  1 | 115 |  17 | 1.095261e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20668 |     - |   205M |   0 | 657 | 638 | 653 |  27 |  1 | 115 |  17 | 1.095261e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20675 |     - |   205M |   0 | 657 | 638 | 656 |  30 |  2 | 115 |  17 | 1.095261e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20675 |     - |   205M |   0 | 657 | 638 | 656 |  30 |  2 | 115 |  17 | 1.095261e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20678 |     - |   205M |   0 | 657 | 638 | 659 |  33 |  3 | 115 |  17 | 1.095261e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20678 |     - |   205M |   0 | 657 | 638 | 659 |  33 |  3 | 115 |  17 | 1.095261e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20685 |     - |   205M |   0 | 657 | 638 | 661 |  35 |  4 | 115 |  17 | 1.095261e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20685 |     - |   205M |   0 | 657 | 638 | 660 |  35 |  4 | 115 |  17 | 1.095261e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20687 |     - |   205M |   0 | 657 | 638 | 659 |  36 |  5 | 115 |  17 | 1.095260e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20687 |     - |   205M |   0 | 657 | 638 | 659 |  36 |  5 | 115 |  17 | 1.095260e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20691 |     - |   205M |   0 | 657 | 638 | 660 |  37 |  6 | 115 |  17 | 1.095260e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20691 |     - |   205M |   0 | 657 | 638 | 660 |  37 |  6 | 115 |  17 | 1.095260e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20695 |     - |   205M |   0 | 657 | 638 | 661 |  38 |  7 | 115 |  17 | 1.095259e+06 | 1.095254e+06 |   0.00%| unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  25.4s|     1 |     0 | 20695 |     - |   205M |   0 | 657 | 638 | 661 |  38 |  7 | 115 |  17 | 1.095259e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20700 |     - |   205M |   0 | 657 | 638 | 662 |  39 |  8 | 115 |  17 | 1.095259e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20749 |     - |   205M |   0 | 657 | 638 | 662 |  39 |  8 | 115 |  17 | 1.095259e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20751 |     - |   205M |   0 | 657 | 638 | 663 |  40 |  9 | 115 |  17 | 1.095259e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20751 |     - |   205M |   0 | 657 | 638 | 663 |  40 |  9 | 115 |  17 | 1.095259e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20754 |     - |   205M |   0 | 657 | 638 | 665 |  42 | 10 | 115 |  17 | 1.095258e+06 | 1.095254e+06 |   0.00%| unknown
#  25.4s|     1 |     0 | 20754 |     - |   205M |   0 | 657 | 638 | 665 |  42 | 10 | 115 |  17 | 1.095258e+06 | 1.095254e+06 |   0.00%| unknown
#  25.5s|     1 |     0 | 20756 |     - |   205M |   0 | 657 | 638 | 666 |  43 | 11 | 115 |  17 | 1.095258e+06 | 1.095254e+06 |   0.00%| unknown
#  25.5s|     1 |     0 | 20756 |     - |   205M |   0 | 657 | 639 | 666 |  43 | 11 | 116 |  17 | 1.095258e+06 | 1.095254e+06 |   0.00%| unknown
#  25.5s|     1 |     0 | 20756 |     - |   205M |   0 | 657 | 635 | 666 |  43 | 11 | 116 |  17 | 1.095258e+06 | 1.095254e+06 |   0.00%| unknown
#  25.5s|     1 |     0 | 20758 |     - |   206M |   0 | 657 | 635 | 667 |  44 | 12 | 116 |  17 | 1.095258e+06 | 1.095254e+06 |   0.00%| unknown
#  25.5s|     1 |     0 | 20758 |     - |   206M |   0 | 657 | 635 | 667 |  44 | 12 | 116 |  17 | 1.095258e+06 | 1.095254e+06 |   0.00%| unknown
#  25.5s|     1 |     0 | 20776 |     - |   206M |   0 | 657 | 636 | 667 |  44 | 14 | 124 |  19 | 1.095254e+06 | 1.095254e+06 |   0.00%| unknown
#
# SCIP Status        : problem is solved [optimal solution found]
# Solving Time (sec) : 25.48
# Solving Nodes      : 1 (total of 7 nodes in 7 runs)
# Primal Bound       : +1.09525419700000e+06 (18 solutions)
# Dual Bound         : +1.09525419700000e+06
# Gap                : 0.00 %
#
# Termination condition:  optimal
# Solver status:  ok
# Solver message:  optimal solution found
# Best feasible objective:  1095254.197
# Best objective bound:  1095254.197
# Gap:  0.0
# Objective: 1095254.1969999801

# %%
GasStorage.export_all_storages()
# Out:
# Results exported to total_export.xlsx
# Results exported to MGS_2023_11_08_13_20_37_584575_export.xlsx
# Results exported to MGS_2023_11_08_13_20_39_143641_export.xlsx
# Results exported to MGS_2023_11_08_13_20_40_682392_export.xlsx
# <div>                            <div id="435398e3-3fd0-4eb6-9fa0-e7f7f07b0a91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("435398e3-3fd0-4eb6-9fa0-e7f7f07b0a91")) {                    Plotly.newPlot(                        "435398e3-3fd0-4eb6-9fa0-e7f7f07b0a91",                        [{"line":{"color":"#ffa600"},"mode":"lines","name":"Max. operations","x":["2024-04-01","2024-04-02","2024-04-03","2024-04-04","2024-04-05","2024-04-06","2024-04-07","2024-04-08","2024-04-09","2024-04-10","2024-04-11","2024-04-12","2024-04-13","2024-04-14","2024-04-15","2024-04-16","2024-04-17","2024-04-18","2024-04-19","2024-04-20","2024-04-21","2024-04-22","2024-04-23","2024-04-24","2024-04-25","2024-04-26","2024-04-27","2024-04-28","2024-04-29","2024-04-30","2024-05-01","2024-05-02","2024-05-03","2024-05-04","2024-05-05","2024-05-06","2024-05-07","2024-05-08","2024-05-09","2024-05-10","2024-05-11","2024-05-12","2024-05-13","2024-05-14","2024-05-15","2024-05-16","2024-05-17","2024-05-18","2024-05-19","2024-05-20","2024-05-21","2024-05-22","2024-05-23","2024-05-24","2024-05-25","2024-05-26","2024-05-27","2024-05-28","2024-05-29","2024-05-30","2024-05-31","2024-06-01","2024-06-02","2024-06-03","2024-06-04","2024-06-05","2024-06-06","2024-06-07","2024-06-08","2024-06-09","2024-06-10","2024-06-11","2024-06-12","2024-06-13","2024-06-14","2024-06-15","2024-06-16","2024-06-17","2024-06-18","2024-06-19","2024-06-20","2024-06-21","2024-06-22","2024-06-23","2024-06-24","2024-06-25","2024-06-26","2024-06-27","2024-06-28","2024-06-29","2024-06-30","2024-07-01","2024-07-02","2024-07-03","2024-07-04","2024-07-05","2024-07-06","2024-07-07","2024-07-08","2024-07-09","2024-07-10","2024-07-11","2024-07-12","2024-07-13","2024-07-14","2024-07-15","2024-07-16","2024-07-17","2024-07-18","2024-07-19","2024-07-20","2024-07-21","2024-07-22","2024-07-23","2024-07-24","2024-07-25","2024-07-26","2024-07-27","2024-07-28","2024-07-29","2024-07-30","2024-07-31","2024-08-01","2024-08-02","2024-08-03","2024-08-04","2024-08-05","2024-08-06","2024-08-07","2024-08-08","2024-08-09","2024-08-10","2024-08-11","2024-08-12","2024-08-13","2024-08-14","2024-08-15","2024-08-16","2024-08-17","2024-08-18","2024-08-19","2024-08-20","2024-08-21","2024-08-22","2024-08-23","2024-08-24","2024-08-25","2024-08-26","2024-08-27","2024-08-28","2024-08-29","2024-08-30","2024-08-31","2024-09-01","2024-09-02","2024-09-03","2024-09-04","2024-09-05","2024-09-06","2024-09-07","2024-09-08","2024-09-09","2024-09-10","2024-09-11","2024-09-12","2024-09-13","2024-09-14","2024-09-15","2024-09-16","2024-09-17","2024-09-18","2024-09-19","2024-09-20","2024-09-21","2024-09-22","2024-09-23","2024-09-24","2024-09-25","2024-09-26","2024-09-27","2024-09-28","2024-09-29","2024-09-30","2024-10-01","2024-10-02","2024-10-03","2024-10-04","2024-10-05","2024-10-06","2024-10-07","2024-10-08","2024-10-09","2024-10-10","2024-10-11","2024-10-12","2024-10-13","2024-10-14","2024-10-15","2024-10-16","2024-10-17","2024-10-18","2024-10-19","2024-10-20","2024-10-21","2024-10-22","2024-10-23","2024-10-24","2024-10-25","2024-10-26","2024-10-27","2024-10-28","2024-10-29","2024-10-30","2024-10-31","2024-11-01","2024-11-02","2024-11-03","2024-11-04","2024-11-05","2024-11-06","2024-11-07","2024-11-08","2024-11-09","2024-11-10","2024-11-11","2024-11-12","2024-11-13","2024-11-14","2024-11-15","2024-11-16","2024-11-17","2024-11-18","2024-11-19","2024-11-20","2024-11-21","2024-11-22","2024-11-23","2024-11-24","2024-11-25","2024-11-26","2024-11-27","2024-11-28","2024-11-29","2024-11-30","2024-12-01","2024-12-02","2024-12-03","2024-12-04","2024-12-05","2024-12-06","2024-12-07","2024-12-08","2024-12-09","2024-12-10","2024-12-11","2024-12-12","2024-12-13","2024-12-14","2024-12-15","2024-12-16","2024-12-17","20 ...
# <div>                            <div id="608e1eb4-b57d-4513-a210-4107594c4cd2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("608e1eb4-b57d-4513-a210-4107594c4cd2")) {                    Plotly.newPlot(                        "608e1eb4-b57d-4513-a210-4107594c4cd2",                        [{"line":{"color":"#ffa600"},"mode":"lines","name":"Max. operations","x":["2024-04-01","2024-04-02","2024-04-03","2024-04-04","2024-04-05","2024-04-06","2024-04-07","2024-04-08","2024-04-09","2024-04-10","2024-04-11","2024-04-12","2024-04-13","2024-04-14","2024-04-15","2024-04-16","2024-04-17","2024-04-18","2024-04-19","2024-04-20","2024-04-21","2024-04-22","2024-04-23","2024-04-24","2024-04-25","2024-04-26","2024-04-27","2024-04-28","2024-04-29","2024-04-30","2024-05-01","2024-05-02","2024-05-03","2024-05-04","2024-05-05","2024-05-06","2024-05-07","2024-05-08","2024-05-09","2024-05-10","2024-05-11","2024-05-12","2024-05-13","2024-05-14","2024-05-15","2024-05-16","2024-05-17","2024-05-18","2024-05-19","2024-05-20","2024-05-21","2024-05-22","2024-05-23","2024-05-24","2024-05-25","2024-05-26","2024-05-27","2024-05-28","2024-05-29","2024-05-30","2024-05-31","2024-06-01","2024-06-02","2024-06-03","2024-06-04","2024-06-05","2024-06-06","2024-06-07","2024-06-08","2024-06-09","2024-06-10","2024-06-11","2024-06-12","2024-06-13","2024-06-14","2024-06-15","2024-06-16","2024-06-17","2024-06-18","2024-06-19","2024-06-20","2024-06-21","2024-06-22","2024-06-23","2024-06-24","2024-06-25","2024-06-26","2024-06-27","2024-06-28","2024-06-29","2024-06-30","2024-07-01","2024-07-02","2024-07-03","2024-07-04","2024-07-05","2024-07-06","2024-07-07","2024-07-08","2024-07-09","2024-07-10","2024-07-11","2024-07-12","2024-07-13","2024-07-14","2024-07-15","2024-07-16","2024-07-17","2024-07-18","2024-07-19","2024-07-20","2024-07-21","2024-07-22","2024-07-23","2024-07-24","2024-07-25","2024-07-26","2024-07-27","2024-07-28","2024-07-29","2024-07-30","2024-07-31","2024-08-01","2024-08-02","2024-08-03","2024-08-04","2024-08-05","2024-08-06","2024-08-07","2024-08-08","2024-08-09","2024-08-10","2024-08-11","2024-08-12","2024-08-13","2024-08-14","2024-08-15","2024-08-16","2024-08-17","2024-08-18","2024-08-19","2024-08-20","2024-08-21","2024-08-22","2024-08-23","2024-08-24","2024-08-25","2024-08-26","2024-08-27","2024-08-28","2024-08-29","2024-08-30","2024-08-31","2024-09-01","2024-09-02","2024-09-03","2024-09-04","2024-09-05","2024-09-06","2024-09-07","2024-09-08","2024-09-09","2024-09-10","2024-09-11","2024-09-12","2024-09-13","2024-09-14","2024-09-15","2024-09-16","2024-09-17","2024-09-18","2024-09-19","2024-09-20","2024-09-21","2024-09-22","2024-09-23","2024-09-24","2024-09-25","2024-09-26","2024-09-27","2024-09-28","2024-09-29","2024-09-30","2024-10-01","2024-10-02","2024-10-03","2024-10-04","2024-10-05","2024-10-06","2024-10-07","2024-10-08","2024-10-09","2024-10-10","2024-10-11","2024-10-12","2024-10-13","2024-10-14","2024-10-15","2024-10-16","2024-10-17","2024-10-18","2024-10-19","2024-10-20","2024-10-21","2024-10-22","2024-10-23","2024-10-24","2024-10-25","2024-10-26","2024-10-27","2024-10-28","2024-10-29","2024-10-30","2024-10-31","2024-11-01","2024-11-02","2024-11-03","2024-11-04","2024-11-05","2024-11-06","2024-11-07","2024-11-08","2024-11-09","2024-11-10","2024-11-11","2024-11-12","2024-11-13","2024-11-14","2024-11-15","2024-11-16","2024-11-17","2024-11-18","2024-11-19","2024-11-20","2024-11-21","2024-11-22","2024-11-23","2024-11-24","2024-11-25","2024-11-26","2024-11-27","2024-11-28","2024-11-29","2024-11-30","2024-12-01","2024-12-02","2024-12-03","2024-12-04","2024-12-05","2024-12-06","2024-12-07","2024-12-08","2024-12-09","2024-12-10","2024-12-11","2024-12-12","2024-12-13","2024-12-14","2024-12-15","2024-12-16","2024-12-17","20 ...
# <div>                            <div id="852b56c4-e39e-4edb-ab91-2692da122485" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("852b56c4-e39e-4edb-ab91-2692da122485")) {                    Plotly.newPlot(                        "852b56c4-e39e-4edb-ab91-2692da122485",                        [{"line":{"color":"#ffa600"},"mode":"lines","name":"Max. operations","x":["2024-04-01","2024-04-02","2024-04-03","2024-04-04","2024-04-05","2024-04-06","2024-04-07","2024-04-08","2024-04-09","2024-04-10","2024-04-11","2024-04-12","2024-04-13","2024-04-14","2024-04-15","2024-04-16","2024-04-17","2024-04-18","2024-04-19","2024-04-20","2024-04-21","2024-04-22","2024-04-23","2024-04-24","2024-04-25","2024-04-26","2024-04-27","2024-04-28","2024-04-29","2024-04-30","2024-05-01","2024-05-02","2024-05-03","2024-05-04","2024-05-05","2024-05-06","2024-05-07","2024-05-08","2024-05-09","2024-05-10","2024-05-11","2024-05-12","2024-05-13","2024-05-14","2024-05-15","2024-05-16","2024-05-17","2024-05-18","2024-05-19","2024-05-20","2024-05-21","2024-05-22","2024-05-23","2024-05-24","2024-05-25","2024-05-26","2024-05-27","2024-05-28","2024-05-29","2024-05-30","2024-05-31","2024-06-01","2024-06-02","2024-06-03","2024-06-04","2024-06-05","2024-06-06","2024-06-07","2024-06-08","2024-06-09","2024-06-10","2024-06-11","2024-06-12","2024-06-13","2024-06-14","2024-06-15","2024-06-16","2024-06-17","2024-06-18","2024-06-19","2024-06-20","2024-06-21","2024-06-22","2024-06-23","2024-06-24","2024-06-25","2024-06-26","2024-06-27","2024-06-28","2024-06-29","2024-06-30","2024-07-01","2024-07-02","2024-07-03","2024-07-04","2024-07-05","2024-07-06","2024-07-07","2024-07-08","2024-07-09","2024-07-10","2024-07-11","2024-07-12","2024-07-13","2024-07-14","2024-07-15","2024-07-16","2024-07-17","2024-07-18","2024-07-19","2024-07-20","2024-07-21","2024-07-22","2024-07-23","2024-07-24","2024-07-25","2024-07-26","2024-07-27","2024-07-28","2024-07-29","2024-07-30","2024-07-31","2024-08-01","2024-08-02","2024-08-03","2024-08-04","2024-08-05","2024-08-06","2024-08-07","2024-08-08","2024-08-09","2024-08-10","2024-08-11","2024-08-12","2024-08-13","2024-08-14","2024-08-15","2024-08-16","2024-08-17","2024-08-18","2024-08-19","2024-08-20","2024-08-21","2024-08-22","2024-08-23","2024-08-24","2024-08-25","2024-08-26","2024-08-27","2024-08-28","2024-08-29","2024-08-30","2024-08-31","2024-09-01","2024-09-02","2024-09-03","2024-09-04","2024-09-05","2024-09-06","2024-09-07","2024-09-08","2024-09-09","2024-09-10","2024-09-11","2024-09-12","2024-09-13","2024-09-14","2024-09-15","2024-09-16","2024-09-17","2024-09-18","2024-09-19","2024-09-20","2024-09-21","2024-09-22","2024-09-23","2024-09-24","2024-09-25","2024-09-26","2024-09-27","2024-09-28","2024-09-29","2024-09-30","2024-10-01","2024-10-02","2024-10-03","2024-10-04","2024-10-05","2024-10-06","2024-10-07","2024-10-08","2024-10-09","2024-10-10","2024-10-11","2024-10-12","2024-10-13","2024-10-14","2024-10-15","2024-10-16","2024-10-17","2024-10-18","2024-10-19","2024-10-20","2024-10-21","2024-10-22","2024-10-23","2024-10-24","2024-10-25","2024-10-26","2024-10-27","2024-10-28","2024-10-29","2024-10-30","2024-10-31","2024-11-01","2024-11-02","2024-11-03","2024-11-04","2024-11-05","2024-11-06","2024-11-07","2024-11-08","2024-11-09","2024-11-10","2024-11-11","2024-11-12","2024-11-13","2024-11-14","2024-11-15","2024-11-16","2024-11-17","2024-11-18","2024-11-19","2024-11-20","2024-11-21","2024-11-22","2024-11-23","2024-11-24","2024-11-25","2024-11-26","2024-11-27","2024-11-28","2024-11-29","2024-11-30","2024-12-01","2024-12-02","2024-12-03","2024-12-04","2024-12-05","2024-12-06","2024-12-07","2024-12-08","2024-12-09","2024-12-10","2024-12-11","2024-12-12","2024-12-13","2024-12-14","2024-12-15","2024-12-16","2024-12-17","20 ...
# <div>                            <div id="74738962-76cd-4443-bbaf-a2b150fe767f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74738962-76cd-4443-bbaf-a2b150fe767f")) {                    Plotly.newPlot(                        "74738962-76cd-4443-bbaf-a2b150fe767f",                        [{"line":{"color":"#ffa600"},"mode":"lines","name":"Max. operations","x":["2024-04-01","2024-04-02","2024-04-03","2024-04-04","2024-04-05","2024-04-06","2024-04-07","2024-04-08","2024-04-09","2024-04-10","2024-04-11","2024-04-12","2024-04-13","2024-04-14","2024-04-15","2024-04-16","2024-04-17","2024-04-18","2024-04-19","2024-04-20","2024-04-21","2024-04-22","2024-04-23","2024-04-24","2024-04-25","2024-04-26","2024-04-27","2024-04-28","2024-04-29","2024-04-30","2024-05-01","2024-05-02","2024-05-03","2024-05-04","2024-05-05","2024-05-06","2024-05-07","2024-05-08","2024-05-09","2024-05-10","2024-05-11","2024-05-12","2024-05-13","2024-05-14","2024-05-15","2024-05-16","2024-05-17","2024-05-18","2024-05-19","2024-05-20","2024-05-21","2024-05-22","2024-05-23","2024-05-24","2024-05-25","2024-05-26","2024-05-27","2024-05-28","2024-05-29","2024-05-30","2024-05-31","2024-06-01","2024-06-02","2024-06-03","2024-06-04","2024-06-05","2024-06-06","2024-06-07","2024-06-08","2024-06-09","2024-06-10","2024-06-11","2024-06-12","2024-06-13","2024-06-14","2024-06-15","2024-06-16","2024-06-17","2024-06-18","2024-06-19","2024-06-20","2024-06-21","2024-06-22","2024-06-23","2024-06-24","2024-06-25","2024-06-26","2024-06-27","2024-06-28","2024-06-29","2024-06-30","2024-07-01","2024-07-02","2024-07-03","2024-07-04","2024-07-05","2024-07-06","2024-07-07","2024-07-08","2024-07-09","2024-07-10","2024-07-11","2024-07-12","2024-07-13","2024-07-14","2024-07-15","2024-07-16","2024-07-17","2024-07-18","2024-07-19","2024-07-20","2024-07-21","2024-07-22","2024-07-23","2024-07-24","2024-07-25","2024-07-26","2024-07-27","2024-07-28","2024-07-29","2024-07-30","2024-07-31","2024-08-01","2024-08-02","2024-08-03","2024-08-04","2024-08-05","2024-08-06","2024-08-07","2024-08-08","2024-08-09","2024-08-10","2024-08-11","2024-08-12","2024-08-13","2024-08-14","2024-08-15","2024-08-16","2024-08-17","2024-08-18","2024-08-19","2024-08-20","2024-08-21","2024-08-22","2024-08-23","2024-08-24","2024-08-25","2024-08-26","2024-08-27","2024-08-28","2024-08-29","2024-08-30","2024-08-31","2024-09-01","2024-09-02","2024-09-03","2024-09-04","2024-09-05","2024-09-06","2024-09-07","2024-09-08","2024-09-09","2024-09-10","2024-09-11","2024-09-12","2024-09-13","2024-09-14","2024-09-15","2024-09-16","2024-09-17","2024-09-18","2024-09-19","2024-09-20","2024-09-21","2024-09-22","2024-09-23","2024-09-24","2024-09-25","2024-09-26","2024-09-27","2024-09-28","2024-09-29","2024-09-30","2024-10-01","2024-10-02","2024-10-03","2024-10-04","2024-10-05","2024-10-06","2024-10-07","2024-10-08","2024-10-09","2024-10-10","2024-10-11","2024-10-12","2024-10-13","2024-10-14","2024-10-15","2024-10-16","2024-10-17","2024-10-18","2024-10-19","2024-10-20","2024-10-21","2024-10-22","2024-10-23","2024-10-24","2024-10-25","2024-10-26","2024-10-27","2024-10-28","2024-10-29","2024-10-30","2024-10-31","2024-11-01","2024-11-02","2024-11-03","2024-11-04","2024-11-05","2024-11-06","2024-11-07","2024-11-08","2024-11-09","2024-11-10","2024-11-11","2024-11-12","2024-11-13","2024-11-14","2024-11-15","2024-11-16","2024-11-17","2024-11-18","2024-11-19","2024-11-20","2024-11-21","2024-11-22","2024-11-23","2024-11-24","2024-11-25","2024-11-26","2024-11-27","2024-11-28","2024-11-29","2024-11-30","2024-12-01","2024-12-02","2024-12-03","2024-12-04","2024-12-05","2024-12-06","2024-12-07","2024-12-08","2024-12-09","2024-12-10","2024-12-11","2024-12-12","2024-12-13","2024-12-14","2024-12-15","2024-12-16","2024-12-17","20 ...

# %%
for i in GasStorage._instances:
    print(i.id)
# Out:
# MGS_2023_11_08_13_20_37_584575
# MGS_2023_11_08_13_20_39_143641
# MGS_2023_11_08_13_20_40_682392

# %%
del GasStorage._instances[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/juzun/tasks/gas_tank/gas_tank/gs_oop.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/juzun/tasks/gas_tank/gas_tank/gs_oop.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> del GasStorage._instances[0]
#
# IndexError: list assignment index out of range

# %%
import pickle
for instance in GasStorage._instances:
    file_name = f'save/{instance.name}.pkl'
    with open(file_name, 'wb') as file:
        pickle.dump(instance.mdl, file)
